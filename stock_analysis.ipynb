# %%
import requests
import json
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# # Import Data (financialmodellingprep.com)

# %%
fmp_api_key = '08f03438c8b31a22e58ce3ec9f6dabf6'

appl_annual_income_statement_response = requests.get("https://financialmodelingprep.com/api/v3/income-statement/AAPL?apikey={}".format(fmp_api_key))
appl_annual_balance_sheet_statement_response = requests.get("https://financialmodelingprep.com/api/v3/balance-sheet-statement/AAPL?apikey={}".format(fmp_api_key))
appl_annual_cash_flow_statement_response = requests.get("https://financialmodelingprep.com/api/v3/cash-flow-statement/AAPL?apikey={}".format(fmp_api_key))

# %%
appl_annual_income_statement = appl_annual_income_statement_response.json()
appl_annual_income_statement
# Out:
# [{'date': '2019-09-28',
#   'symbol': 'AAPL',
#   'fillingDate': '2019-10-31',
#   'acceptedDate': '2019-10-30 18:12:36',
#   'period': 'FY',
#   'revenue': 260174000000,
#   'costOfRevenue': 161782000000,
#   'grossProfit': 98392000000,
#   'grossProfitRatio': 0.3781776810903472,
#   'researchAndDevelopmentExpenses': 16217000000,
#   'generalAndAdministrativeExpenses': 18245000000,
#   'sellingAndMarketingExpenses': 0.0,
#   'otherExpenses': 1807000000,
#   'operatingExpenses': 34462000000,
#   'costAndExpenses': 196244000000,
#   'interestExpense': 3576000000,
#   'depreciationAndAmortization': 12547000000,
#   'ebitda': 76477000000,
#   'ebitdaratio': 0.293945590259,
#   'operatingIncome': 63930000000,
#   'operatingIncomeRatio': 0.245720171885,
#   'totalOtherIncomeExpensesNet': 1807000000,
#   'incomeBeforeTax': 65737000000,
#   'incomeBeforeTaxRatio': 0.252665523842,
#   'incomeTaxExpense': 10481000000,
#   'netIncome': 55256000000,
#   'netIncomeRatio': 0.21238094506,
#   'eps': 11.97,
#   'epsdiluted': 11.89,
#   'weightedAverageShsOut': 4617834000,
#   'weightedAverageShsOutDil': 4648913000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019319000119/0000320193-19-000119-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019319000119/a10-k20199282019.htm'},
#  {'date': '2018-09-29',
#   'symbol': 'AAPL',
#   'fillingDate': '2018-11-05',
#   'acceptedDate': '2018-11-05 08:01:40',
#   'period': 'FY',
#   'revenue': 265595000000,
#   'costOfRevenue': 163756000000,
#   'grossProfit': 101839000000,
#   'grossProfitRatio': 0.38343718820007905,
#   'researchAndDevelopmentExpenses': 14236000000,
#   'generalAndAdministrativeExpenses': 16705000000,
#   'sellingAndMarketingExpenses': 0.0,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 30941000000,
#   'costAndExpenses': 194697000000,
#   'interestExpense': 3240000000,
#   'depreciationAndAmortization': 10903000000,
#   'ebitda': 81801000000,
#   'ebitdaratio': 0.307991490804,
#   'operatingIncome': 70898000000,
#   'operatingIncomeRatio': 0.266940266195,
#   'totalOtherIncomeExpensesNet': 2005000000,
#   'incomeBeforeTax': 72903000000,
#   'incomeBeforeTaxRatio': 0.274489354092,
#   'incomeTaxExpense': 13372000000,
#   'netIncome': 59531000000,
#   'netIncomeRatio': 0.224142020746,
#   'eps': 12.01,
#   'epsdiluted': 11.91,
#   'weightedAverageShsOut': 4955377000,
#   'weightedAverageShsOutDil': 5000109000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019318000145/0000320193-18-000145-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019318000145/a10-k20189292018.htm'},
#  {'date': '2017-09-30',
#   'symbol': 'AAPL',
#   'fillingDate': '2017-11-03',
#   'acceptedDate': '2017-11-03 08:01:37',
#   'period': 'FY',
#   'revenue': 229234000000,
#   'costOfRevenue': 141048000000,
#   'grossProfit': 88186000000,
#   'grossProfitRatio': 0.38469860491899105,
#   'researchAndDevelopmentExpenses': 11581000000,
#   'generalAndAdministrativeExpenses': 15261000000,
#   'sellingAndMarketingExpenses': 0.0,
#   'otherExpenses': 2745000000,
#   'operatingExpenses': 26842000000,
#   'costAndExpenses': 167890000000,
#   'interestExpense': 2323000000,
#   'depreciationAndAmortization': 10157000000,
#   'ebitda': 71501000000,
#   'ebitdaratio': 0.311912718009,
#   'operatingIncome': 61344000000,
#   'operatingIncomeRatio': 0.267604282087,
#   'totalOtherIncomeExpensesNet': 2745000000,
#   'incomeBeforeTax': 64089000000,
#   'incomeBeforeTaxRatio': 0.279578945532,
#   'incomeTaxExpense': 15738000000,
#   'netIncome': 48351000000,
#   'netIncomeRatio': 0.210924208451,
#   'eps': 9.27,
#   'epsdiluted': 9.21,
#   'weightedAverageShsOut': 5217242000,
#   'weightedAverageShsOutDil': 5251692000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019317000070/0000320193-17-000070-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019317000070/a10-k20179302017.htm'},
#  {'date': '2016-09-24',
#   'symbol': 'AAPL',
#   'fillingDate': '2016-10-26',
#   'acceptedDate': '2016-10-26 16:42:16',
#   'period': 'FY',
#   'revenue': 215639000000,
#   'costOfRevenue': 131376000000,
#   'grossProfit': 84263000000,
#   'grossProfitRatio': 0.3907595564809705,
#   'researchAndDevelopmentExpenses': 10045000000,
#   'generalAndAdministrativeExpenses': 14194000000,
#   'sellingAndMarketingExpenses': 0.0,
#   'otherExpenses': 1348000000,
#   'operatingExpenses': 24239000000,
#   'costAndExpenses': 155615000000,
#   'interestExpense': 1456000000,
#   'depreciationAndAmortization': 10505000000,
#   'ebitda': 70529000000,
#   'ebitdaratio': 0.327069778658,
#   'operatingIncome': 60024000000,
#   'operatingIncomeRatio': 0.278354101067,
#   'totalOtherIncomeExpensesNet': 1348000000,
#   'incomeBeforeTax': 61372000000,
#   'incomeBeforeTaxRatio': 0.284605289396,
#   'incomeTaxExpense': 15685000000,
#   'netIncome': 45687000000,
#   'netIncomeRatio': 0.211867983064,
#   'eps': 8.35,
#   'epsdiluted': 8.31,
#   'weightedAverageShsOut': 5470820000,
#   'weightedAverageShsOutDil': 5500281000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000162828016020309/0001628280-16-020309-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000162828016020309/a201610-k9242016.htm'},
#  {'date': '2015-09-26',
#   'symbol': 'AAPL',
#   'fillingDate': '2015-10-28',
#   'acceptedDate': '2015-10-28 16:31:09',
#   'period': 'FY',
#   'revenue': 233715000000,
#   'costOfRevenue': 140089000000,
#   'grossProfit': 93626000000,
#   'grossProfitRatio': 0.4005990201741437,
#   'researchAndDevelopmentExpenses': 8067000000,
#   'generalAndAdministrativeExpenses': 14329000000,
#   'sellingAndMarketingExpenses': 0.0,
#   'otherExpenses': 1285000000,
#   'operatingExpenses': 22396000000,
#   'costAndExpenses': 162485000000,
#   'interestExpense': 733000000,
#   'depreciationAndAmortization': 11257000000,
#   'ebitda': 82487000000,
#   'ebitdaratio': 0.35293840789,
#   'operatingIncome': 71230000000,
#   'operatingIncomeRatio': 0.304772907173,
#   'totalOtherIncomeExpensesNet': 1285000000,
#   'incomeBeforeTax': 72515000000,
#   'incomeBeforeTaxRatio': 0.310271056629,
#   'incomeTaxExpense': 19121000000,
#   'netIncome': 53394000000,
#   'netIncomeRatio': 0.228457736987,
#   'eps': 9.28,
#   'epsdiluted': 9.22,
#   'weightedAverageShsOut': 5753421000,
#   'weightedAverageShsOutDil': 5793069000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000119312515356351/0001193125-15-356351-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000119312515356351/d17062d10k.htm'},
#  {'date': '2014-09-27',
#   'symbol': 'AAPL',
#   'fillingDate': '2014-10-27',
#   'acceptedDate': '2014-10-27 17:11:55',
#   'period': 'FY',
#   'revenue': 182795000000,
#   'costOfRevenue': 112258000000,
#   'grossProfit': 70537000000,
#   'grossProfitRatio': 0.3858803577778386,
#   'researchAndDevelopmentExpenses': 6041000000,
#   'generalAndAdministrativeExpenses': 11993000000,
#   'sellingAndMarketingExpenses': 0.0,
#   'otherExpenses': 980000000,
#   'operatingExpenses': 18034000000,
#   'costAndExpenses': 130292000000,
#   'interestExpense': 384000000,
#   'depreciationAndAmortization': 7946000000,
#   'ebitda': 60449000000,
#   'ebitdaratio': 0.330692852649,
#   'operatingIncome': 52503000000,
#   'operatingIncomeRatio': 0.287223392325,
#   'totalOtherIncomeExpensesNet': 980000000,
#   'incomeBeforeTax': 53483000000,
#   'incomeBeforeTaxRatio': 0.292584589294,
#   'incomeTaxExpense': 13973000000,
#   'netIncome': 39510000000,
#   'netIncomeRatio': 0.216143767609,
#   'eps': 6.49,
#   'epsdiluted': 6.45,
#   'weightedAverageShsOut': 6085572000,
#   'weightedAverageShsOutDil': 6122663000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000119312514383437/0001193125-14-383437-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000119312514383437/d783162d10k.htm'},
#  {'date': '2013-09-28',
#   'symbol': 'AAPL',
#   'fillingDate': '2013-10-30',
#   'acceptedDate': '2013-10-29 20:38:28',
#   'period': 'FY',
#   'revenue': 170910000000,
#   'costOfRevenue': 106606000000,
#   'grossProfit': 64304000000,
#   'grossProfitRatio': 0.3762448072084723,
#   'researchAndDevelopmentExpenses': 4475000000,
#   'generalAndAdministrativeExpenses': 10830000000,
#   'sellingAndMarketingExpenses': 0.0,
#   'otherExpenses': 1156000000,
#   'operatingExpenses': 15305000000,
#   'costAndExpenses': 121911000000,
#   'interestExpense': 136000000,
#   'depreciationAndAmortization': 6757000000,
#   'ebitda': 55756000000,
#   'ebitdaratio': 0.326230179627,
#   'operatingIncome': 48999000000,
#   'operatingIncomeRatio': 0.286694751624,
#   'totalOtherIncomeExpensesNet': 1156000000,
#   'incomeBeforeTax': 50155000000,
#   'incomeBeforeTaxRatio': 0.293458545433,
#   'incomeTaxExpense': 13118000000,
#   'netIncome': 37037000000,
#   'netIncomeRatio': 0.216704698379,
#   'eps': 40.03,
#   'epsdiluted': 39.75,
#   'weightedAverageShsOut': 925331000,
#   'weightedAverageShsOutDil': 931662000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000119312513416534/0001193125-13-416534-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000119312513416534/d590790d10k.htm'},
#  {'date': '2012-09-29',
#   'symbol': 'AAPL',
#   'fillingDate': '2012-10-31',
#   'acceptedDate': '2012-10-31 17:07:19',
#   'period': 'FY',
#   'revenue': 156508000000,
#   'costOfRevenue': 87846000000,
#   'grossProfit': 68662000000,
#   'grossProfitRatio': 0.4387123980882766,
#   'researchAndDevelopmentExpenses': 3381000000,
#   'generalAndAdministrativeExpenses': 10040000000,
#   'sellingAndMarketingExpenses': 0.0,
#   'otherExpenses': 522000000,
#   'operatingExpenses': 13421000000,
#   'costAndExpenses': 101267000000,
#   'interestExpense': 0.0,
#   'depreciationAndAmortization': 3277000000,
#   'ebitda': 58518000000,
#   'ebitdaratio': 0.37389781992,
#   'operatingIncome': 55241000000,
#   'operatingIncomeRatio': 0.35295959312,
#   'totalOtherIncomeExpensesNet': 522000000,
#   'incomeBeforeTax': 55763000000,
#   'incomeBeforeTaxRatio': 0.356294885884,
#   'incomeTaxExpense': 14030000000,
#   'netIncome': 41733000000,
#   'netIncomeRatio': 0.266650906024,
#   'eps': 44.64,
#   'epsdiluted': 44.15,
#   'weightedAverageShsOut': 934818000,
#   'weightedAverageShsOutDil': 945355000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000119312512444068/0001193125-12-444068-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000119312512444068/d411355d10k.htm'},
#  {'date': '2011-09-24',
#   'symbol': 'AAPL',
#   'fillingDate': '2011-10-26',
#   'acceptedDate': '2011-10-26 16:35:25',
#   'period': 'FY',
#   'revenue': 108249000000,
#   'costOfRevenue': 64431000000,
#   'grossProfit': 43818000000,
#   'grossProfitRatio': 0.40478895878945764,
#   'researchAndDevelopmentExpenses': 2429000000,
#   'generalAndAdministrativeExpenses': 7599000000,
#   'sellingAndMarketingExpenses': 0.0,
#   'otherExpenses': 415000000,
#   'operatingExpenses': 10028000000,
#   'costAndExpenses': 74459000000,
#   'interestExpense': 0.0,
#   'depreciationAndAmortization': 1814000000,
#   'ebitda': 35604000000,
#   'ebitdaratio': 0.328908350193,
#   'operatingIncome': 33790000000,
#   'operatingIncomeRatio': 0.312150689614,
#   'totalOtherIncomeExpensesNet': 415000000,
#   'incomeBeforeTax': 34205000000,
#   'incomeBeforeTaxRatio': 0.315984443274,
#   'incomeTaxExpense': 8283000000,
#   'netIncome': 25922000000,
#   'netIncomeRatio': 0.239466415394,
#   'eps': 28.05,
#   'epsdiluted': 27.68,
#   'weightedAverageShsOut': 924258000,
#   'weightedAverageShsOutDil': 936645000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000119312511282113/0001193125-11-282113-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000119312511282113/d220209d10k.htm'},
#  {'date': '2010-09-25',
#   'symbol': 'AAPL',
#   'fillingDate': '2010-10-27',
#   'acceptedDate': '2010-10-27 16:36:21',
#   'period': 'FY',
#   'revenue': 65225000000,
#   'costOfRevenue': 39541000000,
#   'grossProfit': 25684000000,
#   'grossProfitRatio': 0.39377539287083174,
#   'researchAndDevelopmentExpenses': 1782000000,
#   'generalAndAdministrativeExpenses': 5517000000,
#   'sellingAndMarketingExpenses': 0.0,
#   'otherExpenses': 155000000,
#   'operatingExpenses': 7299000000,
#   'costAndExpenses': 46840000000,
#   'interestExpense': 0.0,
#   'depreciationAndAmortization': 1027000000,
#   'ebitda': 19412000000,
#   'ebitdaratio': 0.297615944806,
#   'operatingIncome': 18385000000,
#   'operatingIncomeRatio': 0.281870448448,
#   'totalOtherIncomeExpensesNet': 155000000,
#   'incomeBeforeTax': 18540000000,
#   'incomeBeforeTaxRatio': 0.284246837869,
#   'incomeTaxExpense': 4527000000,
#   'netIncome': 14013000000,
#   'netIncomeRatio': 0.214840935224,
#   'eps': 15.41,
#   'epsdiluted': 15.15,
#   'weightedAverageShsOut': 909461000,
#   'weightedAverageShsOutDil': 924712000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000119312510238044/0001193125-10-238044-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000119312510238044/d10k.htm'},
#  {'date': '2009-09-26',
#   'symbol': 'AAPL',
#   'fillingDate': '2009-10-27',
#   'acceptedDate': '2009-10-27 16:18:29',
#   'period': 'FY',
#   'revenue': 36537000000,
#   'costOfRevenue': 23397000000,
#   'grossProfit': 13140000000,
#   'grossProfitRatio': 0.3596354380491009,
#   'researchAndDevelopmentExpenses': 1333000000,
#   'generalAndAdministrativeExpenses': 4149000000,
#   'sellingAndMarketingExpenses': 0.0,
#   'otherExpenses': 326000000,
#   'operatingExpenses': 5482000000,
#   'costAndExpenses': 28879000000,
#   'interestExpense': 0.0,
#   'depreciationAndAmortization': 703000000,
#   'ebitda': 8361000000,
#   'ebitdaratio': 0.2288365218819279,
#   'operatingIncome': 7658000000,
#   'operatingIncomeRatio': 0.2095957522511427,
#   'totalOtherIncomeExpensesNet': 326000000,
#   'incomeBeforeTax': 7984000000,
#   'incomeBeforeTaxRatio': 0.21851821441278704,
#   'incomeTaxExpense': 2280000000,
#   'netIncome': 5704000000,
#   'netIncomeRatio': 0.15611571831294305,
#   'eps': 6.39,
#   'epsdiluted': 6.29,
#   'weightedAverageShsOut': 893016000,
#   'weightedAverageShsOutDil': 907005000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000119312509214859/0001193125-09-214859-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000119312509214859/d10k.htm'},
#  {'date': '2008-09-27',
#   'symbol': 'AAPL',
#   'fillingDate': '2008-11-05',
#   'acceptedDate': '2008-11-05 06:16:23',
#   'period': 'FY',
#   'revenue': 32479000000,
#   'costOfRevenue': 21334000000,
#   'grossProfit': 11145000000,
#   'grossProfitRatio': 0.3431448012561963,
#   'researchAndDevelopmentExpenses': 1109000000,
#   'generalAndAdministrativeExpenses': 3761000000,
#   'sellingAndMarketingExpenses': 0.0,
#   'otherExpenses': 620000000,
#   'operatingExpenses': 4870000000,
#   'costAndExpenses': 26204000000,
#   'interestExpense': 0.0,
#   'depreciationAndAmortization': 473000000,
#   'ebitda': 6748000000,
#   'ebitdaratio': 0.2077650173958558,
#   'operatingIncome': 6275000000,
#   'operatingIncomeRatio': 0.19320176113796608,
#   'totalOtherIncomeExpensesNet': 620000000,
#   'incomeBeforeTax': 6895000000,
#   'incomeBeforeTaxRatio': 0.21229101881215554,
#   'incomeTaxExpense': 2061000000,
#   'netIncome': 4834000000,
#   'netIncomeRatio': 0.14883463160811602,
#   'eps': 5.48,
#   'epsdiluted': 5.36,
#   'weightedAverageShsOut': 881592000,
#   'weightedAverageShsOutDil': 902139000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000119312508224958/0001193125-08-224958-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000119312508224958/d10k.htm'},
#  {'date': '2007-09-29',
#   'symbol': 'AAPL',
#   'fillingDate': '2007-11-15',
#   'acceptedDate': '2007-11-15 16:49:37',
#   'period': 'FY',
#   'revenue': 24006000000,
#   'costOfRevenue': 15852000000,
#   'grossProfit': 8154000000,
#   'grossProfitRatio': 0.33966508372906773,
#   'researchAndDevelopmentExpenses': 782000000,
#   'generalAndAdministrativeExpenses': 2963000000,
#   'sellingAndMarketingExpenses': 0.0,
#   'otherExpenses': 599000000,
#   'operatingExpenses': 3745000000,
#   'costAndExpenses': 19597000000,
#   'interestExpense': 0.0,
#   'depreciationAndAmortization': 317000000,
#   'ebitda': 4726000000,
#   'ebitdaratio': 0.1968674498042156,
#   'operatingIncome': 4409000000,
#   'operatingIncomeRatio': 0.1836624177289011,
#   'totalOtherIncomeExpensesNet': 599000000,
#   'incomeBeforeTax': 5008000000,
#   'incomeBeforeTaxRatio': 0.20861451303840706,
#   'incomeTaxExpense': 1512000000,
#   'netIncome': 3496000000,
#   'netIncomeRatio': 0.1456302591018912,
#   'eps': 4.04,
#   'epsdiluted': 3.93,
#   'weightedAverageShsOut': 864595000,
#   'weightedAverageShsOutDil': 889292000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000104746907009340/0001047469-07-009340-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000104746907009340/a2181030z10-k.htm'},
#  {'date': '2006-09-30',
#   'symbol': 'AAPL',
#   'fillingDate': '2006-12-29',
#   'acceptedDate': '2006-12-29 06:05:58',
#   'period': 'FY',
#   'revenue': 13931000000,
#   'costOfRevenue': 9888000000,
#   'grossProfit': 4043000000,
#   'grossProfitRatio': 0.29021606489124974,
#   'researchAndDevelopmentExpenses': 534000000,
#   'generalAndAdministrativeExpenses': 1859000000,
#   'sellingAndMarketingExpenses': 0.0,
#   'otherExpenses': 165000000,
#   'operatingExpenses': 2393000000,
#   'costAndExpenses': 12281000000,
#   'interestExpense': 0.0,
#   'depreciationAndAmortization': 225000000,
#   'ebitda': 1875000000,
#   'ebitdaratio': 0.134591917306726,
#   'operatingIncome': 1650000000,
#   'operatingIncomeRatio': 0.11844088722991888,
#   'totalOtherIncomeExpensesNet': 165000000,
#   'incomeBeforeTax': 1815000000,
#   'incomeBeforeTaxRatio': 0.13028497595291078,
#   'incomeTaxExpense': 480000000,
#   'netIncome': 1335000000,
#   'netIncomeRatio': 0.09582944512238892,
#   'eps': 1.65,
#   'epsdiluted': 1.56,
#   'weightedAverageShsOut': 808439000,
#   'weightedAverageShsOutDil': 856780000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000110465906084288/0001104659-06-084288-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000110465906084288/a06-25759_210k.htm'},
#  {'date': '2005-09-24',
#   'symbol': 'AAPL',
#   'fillingDate': '2005-12-01',
#   'acceptedDate': '2005-11-30 21:22:48',
#   'period': 'FY',
#   'revenue': 13931000000,
#   'costOfRevenue': 9888000000,
#   'grossProfit': 4043000000,
#   'grossProfitRatio': 0.29021606489124974,
#   'researchAndDevelopmentExpenses': 534000000,
#   'generalAndAdministrativeExpenses': 1859000000,
#   'sellingAndMarketingExpenses': 0.0,
#   'otherExpenses': 165000000,
#   'operatingExpenses': 2393000000,
#   'costAndExpenses': 12281000000,
#   'interestExpense': 0.0,
#   'depreciationAndAmortization': 179000000,
#   'ebitda': 1829000000,
#   'ebitdaratio': 0.13128992893546768,
#   'operatingIncome': 1650000000,
#   'operatingIncomeRatio': 0.11844088722991888,
#   'totalOtherIncomeExpensesNet': 165000000,
#   'incomeBeforeTax': 1815000000,
#   'incomeBeforeTaxRatio': 0.13028497595291078,
#   'incomeTaxExpense': 480000000,
#   'netIncome': 1335000000,
#   'netIncomeRatio': 0.09582944512238892,
#   'eps': 1.65,
#   'epsdiluted': 1.56,
#   'weightedAverageShsOut': 808439000,
#   'weightedAverageShsOutDil': 856780000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000110465905058421/0001104659-05-058421-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000110465905058421/a05-20674_110k.htm'},
#  {'date': '2004-09-25',
#   'symbol': 'AAPL',
#   'fillingDate': '2004-12-03',
#   'acceptedDate': '2004-12-02 18:05:49',
#   'period': 'FY',
#   'revenue': 8279000000,
#   'costOfRevenue': 6020000000,
#   'grossProfit': 2259000000,
#   'grossProfitRatio': 0.2728590409469743,
#   'researchAndDevelopmentExpenses': 489000000,
#   'generalAndAdministrativeExpenses': 1421000000,
#   'sellingAndMarketingExpenses': 0.0,
#   'otherExpenses': 23000000,
#   'operatingExpenses': 1933000000,
#   'costAndExpenses': 7953000000,
#   'interestExpense': 0.0,
#   'depreciationAndAmortization': 150000000,
#   'ebitda': 476000000,
#   'ebitdaratio': 0.057494866529774126,
#   'operatingIncome': 326000000,
#   'operatingIncomeRatio': 0.03937673632081169,
#   'totalOtherIncomeExpensesNet': 53000000,
#   'incomeBeforeTax': 383000000,
#   'incomeBeforeTaxRatio': 0.04626162580021742,
#   'incomeTaxExpense': 107000000,
#   'netIncome': 276000000,
#   'netIncomeRatio': 0.03333735958449088,
#   'eps': 0.74,
#   'epsdiluted': 0.71,
#   'weightedAverageShsOut': 371590000,
#   'weightedAverageShsOutDil': 387311000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000104746904035975/0001047469-04-035975-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000104746904035975/a2147337z10-k.htm'},
#  {'date': '2003-09-27',
#   'symbol': 'AAPL',
#   'fillingDate': '2003-12-19',
#   'acceptedDate': '2003-12-19 17:25:45',
#   'period': 'FY',
#   'revenue': 6207000000,
#   'costOfRevenue': 4499000000,
#   'grossProfit': 1708000000,
#   'grossProfitRatio': 0.2751731915579185,
#   'researchAndDevelopmentExpenses': 471000000,
#   'generalAndAdministrativeExpenses': 1212000000,
#   'sellingAndMarketingExpenses': 0.0,
#   'otherExpenses': 26000000,
#   'operatingExpenses': 1709000000,
#   'costAndExpenses': 6208000000,
#   'interestExpense': 0.0,
#   'depreciationAndAmortization': 113000000,
#   'ebitda': 112000000,
#   'ebitdaratio': 0.018044143708715966,
#   'operatingIncome': -1000000.0,
#   'operatingIncomeRatio': -0.00016110842597067828,
#   'totalOtherIncomeExpensesNet': 83000000,
#   'incomeBeforeTax': 92000000,
#   'incomeBeforeTaxRatio': 0.014821975189302401,
#   'incomeTaxExpense': 24000000,
#   'netIncome': 69000000,
#   'netIncomeRatio': 0.011116481391976801,
#   'eps': 0.19,
#   'epsdiluted': 0.19,
#   'weightedAverageShsOut': 360631000,
#   'weightedAverageShsOutDil': 363466000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000104746903041604/0001047469-03-041604-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000104746903041604/a2124888z10-k.htm'},
#  {'date': '2002-09-28',
#   'symbol': 'AAPL',
#   'fillingDate': '2002-12-19',
#   'acceptedDate': '2002-12-19 17:20:21',
#   'period': 'FY',
#   'revenue': 5742000000,
#   'costOfRevenue': 4139000000,
#   'grossProfit': 1603000000,
#   'grossProfitRatio': 0.2791710205503309,
#   'researchAndDevelopmentExpenses': 446000000,
#   'generalAndAdministrativeExpenses': 1111000000,
#   'sellingAndMarketingExpenses': 0.0,
#   'otherExpenses': 29000000,
#   'operatingExpenses': 1586000000,
#   'costAndExpenses': 5725000000,
#   'interestExpense': 0.0,
#   'depreciationAndAmortization': 118000000,
#   'ebitda': 135000000,
#   'ebitdaratio': 0.023510971786833857,
#   'operatingIncome': 17000000,
#   'operatingIncomeRatio': 0.0029606408916753742,
#   'totalOtherIncomeExpensesNet': 112000000,
#   'incomeBeforeTax': 87000000,
#   'incomeBeforeTaxRatio': 0.015151515151515152,
#   'incomeTaxExpense': 22000000,
#   'netIncome': 65000000,
#   'netIncomeRatio': 0.011320097526994078,
#   'eps': 0.18,
#   'epsdiluted': 0.18,
#   'weightedAverageShsOut': 355022000,
#   'weightedAverageShsOutDil': 361785000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000104746902007674/0001047469-02-007674-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000104746902007674/a2096490z10-k.htm'},
#  {'date': '2001-09-29',
#   'symbol': 'AAPL',
#   'fillingDate': '2001-12-21',
#   'acceptedDate': '2001-12-21 00:00:00',
#   'period': 'FY',
#   'revenue': 5363000000,
#   'costOfRevenue': 4128000000,
#   'grossProfit': 1235000000,
#   'grossProfitRatio': 0.2302815588290136,
#   'researchAndDevelopmentExpenses': 430000000,
#   'generalAndAdministrativeExpenses': 1138000000,
#   'sellingAndMarketingExpenses': 0.0,
#   'otherExpenses': 11000000,
#   'operatingExpenses': 1579000000,
#   'costAndExpenses': 5707000000,
#   'interestExpense': 0.0,
#   'depreciationAndAmortization': 102000000,
#   'ebitda': -242000000,
#   'ebitdaratio': -0.04512399776244639,
#   'operatingIncome': -344000000,
#   'operatingIncomeRatio': -0.06414320343091554,
#   'totalOtherIncomeExpensesNet': 217000000,
#   'incomeBeforeTax': -52000000,
#   'incomeBeforeTaxRatio': -0.009696065634905836,
#   'incomeTaxExpense': 15000000,
#   'netIncome': 25000000,
#   'netIncomeRatio': -0.004661570016781652,
#   'eps': -0.11,
#   'epsdiluted': -0.11,
#   'weightedAverageShsOut': 345613000,
#   'weightedAverageShsOutDil': 345613000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000091205701544436/0000912057-01-544436-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000091205701544436/a2066171z10-k405.htm'}]

# %%
appl_annual_income_statement = pd.DataFrame(appl_annual_income_statement)
appl_annual_income_statement.head()
# Out:
#          date symbol fillingDate         acceptedDate period       revenue  \
# 0  2019-09-28   AAPL  2019-10-31  2019-10-30 18:12:36     FY  260174000000
# 1  2018-09-29   AAPL  2018-11-05  2018-11-05 08:01:40     FY  265595000000
# 2  2017-09-30   AAPL  2017-11-03  2017-11-03 08:01:37     FY  229234000000
# 3  2016-09-24   AAPL  2016-10-26  2016-10-26 16:42:16     FY  215639000000
# 4  2015-09-26   AAPL  2015-10-28  2015-10-28 16:31:09     FY  233715000000
#
#    costOfRevenue   grossProfit  grossProfitRatio  \
# 0   161782000000   98392000000          0.378178
# 1   163756000000  101839000000          0.383437
# 2   141048000000   88186000000          0.384699
# 3   131376000000   84263000000          0.390760
# 4   140089000000   93626000000          0.400599
#
#    researchAndDevelopmentExpenses  ...  incomeBeforeTaxRatio  \
# 0                     16217000000  ...              0.252666
# 1                     14236000000  ...              0.274489
# 2                     11581000000  ...              0.279579
# 3                     10045000000  ...              0.284605
# 4                      8067000000  ...              0.310271
#
#    incomeTaxExpense    netIncome  netIncomeRatio    eps  epsdiluted  \
# 0       10481000000  55256000000        0.212381  11.97       11.89
# 1       13372000000  59531000000        0.224142  12.01       11.91
# 2       15738000000  48351000000        0.210924   9.27        9.21
# 3       15685000000  45687000000        0.211868   8.35        8.31
# 4       19121000000  53394000000        0.228458   9.28        9.22
#
#    weightedAverageShsOut  weightedAverageShsOutDil  \
# 0             4617834000                4648913000
# 1             4955377000                5000109000
# 2             5217242000                5251692000
# 3             5470820000                5500281000
# 4             5753421000                5793069000
#
#                                                 link  \
# 0  https://www.sec.gov/Archives/edgar/data/320193...
# 1  https://www.sec.gov/Archives/edgar/data/320193...
# 2  https://www.sec.gov/Archives/edgar/data/320193...
# 3  https://www.sec.gov/Archives/edgar/data/320193...
# 4  https://www.sec.gov/Archives/edgar/data/320193...
#
#                                            finalLink
# 0  https://www.sec.gov/Archives/edgar/data/320193...
# 1  https://www.sec.gov/Archives/edgar/data/320193...
# 2  https://www.sec.gov/Archives/edgar/data/320193...
# 3  https://www.sec.gov/Archives/edgar/data/320193...
# 4  https://www.sec.gov/Archives/edgar/data/320193...
#
# [5 rows x 33 columns]

# %%
income_statement_col = appl_annual_income_statement.columns.tolist()
income_statement_row = appl_annual_income_statement.shape[0]

# %%
appl_annual_balance_sheet_statement = appl_annual_balance_sheet_statement_response.json()
appl_annual_balance_sheet_statement = pd.DataFrame(appl_annual_balance_sheet_statement)
appl_annual_balance_sheet_statement.head()
# Out:
#          date symbol fillingDate         acceptedDate period  \
# 0  2019-09-28   AAPL  2019-10-31  2019-10-30 18:12:36     FY
# 1  2018-09-29   AAPL  2018-11-05  2018-11-05 08:01:40     FY
# 2  2017-09-30   AAPL  2017-11-03  2017-11-03 08:01:37     FY
# 3  2016-09-24   AAPL  2016-10-26  2016-10-26 16:42:16     FY
# 4  2015-09-26   AAPL  2015-10-28  2015-10-28 16:31:09     FY
#
#    cashAndCashEquivalents  shortTermInvestments  cashAndShortTermInvestments  \
# 0             48844000000           51713000000                 100557000000
# 1             25913000000           40388000000                  66301000000
# 2             20289000000           53892000000                  74181000000
# 3             20484000000           46671000000                  67155000000
# 4             21120000000           20481000000                  41601000000
#
#    netReceivables   inventory  ...  retainedEarnings  \
# 0     22926000000  4106000000  ...       45898000000
# 1     23186000000  3956000000  ...       70400000000
# 2     17874000000  4855000000  ...       98330000000
# 3     15754000000  2132000000  ...       96364000000
# 4     16849000000  2349000000  ...       92284000000
#
#    accumulatedOtherComprehensiveIncomeLoss  othertotalStockholdersEquity  \
# 0                            -5.840000e+08                  4.073076e+10
# 1                            -3.454000e+09                  3.544601e+10
# 2                            -1.500000e+08                  3.074080e+10
# 3                             6.340000e+08                  2.591483e+10
# 4                            -3.450000e+08                  2.183725e+10
#
#    totalStockholdersEquity  totalLiabilitiesAndStockholdersEquity  \
# 0              90488000000                           338516000000
# 1             107147000000                           365725000000
# 2             134047000000                           375319000000
# 3             128249000000                           321686000000
# 4             119355000000                           290479000000
#
#    totalInvestments     totalDebt      netDebt  \
# 0      157054000000  102067000000  53223000000
# 1      211187000000  102519000000  76606000000
# 2      248606000000  103703000000  83414000000
# 3      217101000000   78927000000  58443000000
# 4      184546000000   55963000000  34843000000
#
#                                                 link  \
# 0  https://www.sec.gov/Archives/edgar/data/320193...
# 1  https://www.sec.gov/Archives/edgar/data/320193...
# 2  https://www.sec.gov/Archives/edgar/data/320193...
# 3  https://www.sec.gov/Archives/edgar/data/320193...
# 4  https://www.sec.gov/Archives/edgar/data/320193...
#
#                                            finalLink
# 0  https://www.sec.gov/Archives/edgar/data/320193...
# 1  https://www.sec.gov/Archives/edgar/data/320193...
# 2  https://www.sec.gov/Archives/edgar/data/320193...
# 3  https://www.sec.gov/Archives/edgar/data/320193...
# 4  https://www.sec.gov/Archives/edgar/data/320193...
#
# [5 rows x 46 columns]

# %%
balance_sheet_col = appl_annual_balance_sheet_statement.columns.tolist()
balance_sheet_row = appl_annual_balance_sheet_statement.shape[0]

# %%
appl_annual_cash_flow_statement = appl_annual_cash_flow_statement_response.json()
appl_annual_cash_flow_statement = pd.DataFrame(appl_annual_cash_flow_statement)
appl_annual_cash_flow_statement.head()
# Out:
#          date symbol fillingDate         acceptedDate period    netIncome  \
# 0  2019-09-28   AAPL  2019-10-31  2019-10-30 18:12:36     FY  55256000000
# 1  2018-09-29   AAPL  2018-11-05  2018-11-05 08:01:40     FY  59531000000
# 2  2017-09-30   AAPL  2017-11-03  2017-11-03 08:01:37     FY  48351000000
# 3  2016-09-24   AAPL  2016-10-26  2016-10-26 16:42:16     FY  45687000000
# 4  2015-09-26   AAPL  2015-10-28  2015-10-28 16:31:09     FY  53394000000
#
#    depreciationAndAmortization  deferredIncomeTax  stockBasedCompensation  \
# 0                  12547000000         -340000000            6.068000e+09
# 1                  10903000000       -32590000000            5.340000e+09
# 2                  10157000000         5966000000            4.840000e+09
# 3                  10505000000         4938000000            4.210000e+09
# 4                  11257000000         1382000000            3.586000e+09
#
#    changeInWorkingCapital  ...  netCashUsedProvidedByFinancingActivities  \
# 0           -4.140000e+09  ...                              -90976000000
# 1            3.425000e+10  ...                              -87876000000
# 2           -5.716000e+09  ...                              -17347000000
# 3            4.840000e+08  ...                              -20483000000
# 4            1.164700e+10  ...                              -17716000000
#
#    effectOfForexChangesOnCash  netChangeInCash  cashAtEndOfPeriod  \
# 0                         0.0      24311000000        50224000000
# 1                         0.0       5624000000        25913000000
# 2                         0.0       -195000000        20289000000
# 3                         0.0       -636000000        20484000000
# 4                         0.0       7276000000        21120000000
#
#    cashAtBeginningOfPeriod  operatingCashFlow  capitalExpenditure  \
# 0              25913000000        69391000000         10495000000
# 1              20289000000        77434000000         13313000000
# 2              20484000000        63598000000         12795000000
# 3              21120000000        65824000000         13548000000
# 4              13844000000        81266000000         11488000000
#
#    freeCashFlow                                               link  \
# 0   58896000000  https://www.sec.gov/Archives/edgar/data/320193...
# 1   64121000000  https://www.sec.gov/Archives/edgar/data/320193...
# 2   50803000000  https://www.sec.gov/Archives/edgar/data/320193...
# 3   52276000000  https://www.sec.gov/Archives/edgar/data/320193...
# 4   69778000000  https://www.sec.gov/Archives/edgar/data/320193...
#
#                                            finalLink
# 0  https://www.sec.gov/Archives/edgar/data/320193...
# 1  https://www.sec.gov/Archives/edgar/data/320193...
# 2  https://www.sec.gov/Archives/edgar/data/320193...
# 3  https://www.sec.gov/Archives/edgar/data/320193...
# 4  https://www.sec.gov/Archives/edgar/data/320193...
#
# [5 rows x 37 columns]

# %%
cash_flow_col = appl_annual_cash_flow_statement.columns.tolist()
cash_flow_row = appl_annual_cash_flow_statement.shape[0]

# %%
def fmp_get_annual_financial_statement(ticker, statement_type, api_key):
    """
    This function aims to retrieve the selected annual financial statements of a selected company
    available in Financial Modeling Prep website. Depending on availability, all years will be retrieved.

    :param ticker: listed company ticker symbol
    :type ticker: str
    :param statement_type: type of financial statement (income-, balance-sheet- or cash-flow-statement)
    :type statement_type: str
    :param api_key: user's api key in Financial Modeling Prep
    :type api_key: str
    :return: annual financial statements of the selected company
    :rtype: pd.DataFrame
    """

    annual_statement_response = requests.get("https://financialmodelingprep.com/api/v3/{}/{}?apikey={}"
                                             .format(statement_type, ticker, api_key))

    if annual_statement_response.status_code == 200:
        annual_statement = annual_statement_response.json()
    else:
        print('Get annual {} failed with {}'
              .format(statement_type, annual_statement_response.status_code))

    return pd.DataFrame(annual_statement)

# %%
def fmp_get_company_profile_data(ticker, api_key):
    """
    This function aims to retrieve the selected company's profile data from financialmodelingprep.com like market cap,
    industry, sector, price, beta etc.

    :param ticker: listed company ticker symbol
    :type ticker: str
    :param api_key: user's api key in financialmodelingprep.com
    :type api_key: str
    :return: profile data of the selected company
    :rtype: pd.DataFrame
    """

    company_profile_response = requests.get("https://financialmodelingprep.com/api/v3/profile/{}?apikey={}"
                                            .format(ticker, api_key))

    if company_profile_response.status_code == 200:
        company_profile = company_profile_response.json()
    else:
        raise ValueError('Get {} company profile data failed with {}'
              .format(ticker, company_profile_response.status_code))

    # if company profile is empty, there might be something wrong while retrieving data. Throw ValueError.
    if pd.DataFrame(company_profile).empty:
        raise ValueError('No data retrieved! Check API!')

    return pd.DataFrame(company_profile)

# %%
fmp_get_company_profile_data('DIS', fmp_api_key)
# Out:
#   Symbol     AssetType                     Name  \
# 0    DIS  Common Stock  The Walt Disney Company
#
#                                          Description Exchange Currency  \
# 0  The Walt Disney Company, together with its sub...     NYSE      USD
#
#   Country                  Sector       Industry  \
# 0     USA  Communication Services  Entertainment
#
#                                              Address  ... ShortPercentFloat  \
# 0  500 South Buena Vista Street, Burbank, CA, Uni...  ...            0.0144
#
#   PercentInsiders PercentInstitutions ForwardAnnualDividendRate  \
# 0           0.202              66.286                         0
#
#   ForwardAnnualDividendYield PayoutRatio DividendDate ExDividendDate  \
# 0                          0      0.7686   2020-01-16     2019-12-13
#
#   LastSplitFactor LastSplitDate
# 0      10000:9865    2007-06-13
#
# [1 rows x 59 columns]

# %%
fmp_get_annual_financial_statement('DIS', 'income-statement', fmp_api_key)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-0c35f3be232e> in <module>
# ----> 1 get_annual_financial_statement('income-statement', 'DIS', fmp_api_key)
#
# <ipython-input-77-2bbd736a6442> in get_annual_financial_statement(ticker, statement_type, api_key)
#      23               .format(statement_type, annual_statement_response.status_code))
#      24
# ---> 25     return pd.DataFrame(annual_statement)
#
# c:\users\egg_o\desktop\stock-analysis\venv\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     465
#     466         elif isinstance(data, dict):
# --> 467             mgr = init_dict(data, index, columns, dtype=dtype)
#     468         elif isinstance(data, ma.MaskedArray):
#     469             import numpy.ma.mrecords as mrecords
#
# c:\users\egg_o\desktop\stock-analysis\venv\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# c:\users\egg_o\desktop\stock-analysis\venv\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      76         # figure out the index, if necessary
#      77         if index is None:
# ---> 78             index = extract_index(arrays)
#      79         else:
#      80             index = ensure_index(index)
#
# c:\users\egg_o\desktop\stock-analysis\venv\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     385
#     386         if not indexes and not raw_lengths:
# --> 387             raise ValueError("If using all scalar values, you must pass an index")
#     388
#     389         if have_series:
#
# ValueError: If using all scalar values, you must pass an index

# %%
def fmp_collect_companies_data(tickers_list, api_key):
    """
    This function aims to collect all financial data from the income, balance sheet and cash flow statement of all the
    selected companies in the tickers_list and combine them into a pandas dataset.
    Companies' profile data will be collected here and will be returned as a second pandas dataset

    :param tickers_list: a list of tickers that should be collected
    :type tickers_list: list
    :param api_key: user's api key in financialmodelingprep.com
    :type api_key: str
    :return: a dataframe with financial data from the selected companies
    :rtype: pd.DataFrame
    :return: a dataframe with profile data from the selected companies
    :rtype: pd.DataFrame
    """

    companies_profile_data = pd.DataFrame()
    companies_financial_data = pd.DataFrame()

    try:
        for ticker in tickers_list:
            print('        Getting {} data...'.format(ticker))
            # get current company's financial and profile data
            profile_data = get_company_profile_data(ticker, api_key)
            income_statement = get_annual_financial_statement(ticker, 'income-statement', api_key)
            balance_sheet_statement = get_annual_financial_statement(ticker, 'balance-sheet-statement', api_key)
            cash_flow_statement = get_annual_financial_statement(ticker, 'cash-flow-statement', api_key)

            # concatenate data from all 3 financial statements horizontally
            financial_data = pd.concat([income_statement, balance_sheet_statement, cash_flow_statement], axis=1)

            # append retrieved data of the current company to the final dataframes
            companies_financial_data = companies_financial_data.append(financial_data, ignore_index=True)
            companies_profile_data = companies_profile_data.append(profile_data, ignore_index=True)
            print('        {} data received!'.format(ticker))
    except ValueError:
        print('    Data collection interrupted! Continuing rest of the process..')

    # remove duplicated columns which are retrieved everytime a financial statement is requested
    companies_financial_data = companies_financial_data.loc[:, ~companies_financial_data.columns.duplicated()]

    return companies_financial_data, companies_profile_data

# %% [markdown]
# # Import Data (alphavantage.co)

# %%
alpha_api_key = 'XHBL41C64CVIQFNJ'

dis_annual_income_statement_response = requests.get("https://www.alphavantage.co/query?function=INCOME_STATEMENT&symbol=DIS&apikey={}".format(alpha_api_key))
dis_annual_balance_sheet_statement_response = requests.get("https://www.alphavantage.co/query?function=BALANCE_SHEET&symbol=DIS&apikey={}".format(alpha_api_key))
dis_annual_cash_flow_statement_response = requests.get("https://www.alphavantage.co/query?function=CASH_FLOW&symbol=DIS&apikey={}".format(alpha_api_key))

# %%
dis_annual_income_statement_response.json()
# Out:
# {'symbol': 'DIS',
#  'annualReports': [{'fiscalDateEnding': '2019-09-30',
#    'reportedCurrency': 'USD',
#    'totalRevenue': '69570000000',
#    'totalOperatingExpense': '57719000000',
#    'costOfRevenue': '42018000000',
#    'grossProfit': '27552000000',
#    'ebit': '19350000000',
#    'netIncome': '11054000000',
#    'researchAndDevelopment': 'None',
#    'effectOfAccountingCharges': 'None',
#    'incomeBeforeTax': '13944000000',
#    'minorityInterest': '13975000000',
#    'sellingGeneralAdministrative': '11541000000',
#    'otherNonOperatingIncome': 'None',
#    'operatingIncome': '11851000000',
#    'otherOperatingExpense': 'None',
#    'interestExpense': '1246000000',
#    'taxProvision': '3031000000',
#    'interestIncome': '268000000',
#    'netInterestIncome': '-978000000',
#    'extraordinaryItems': '647000000',
#    'nonRecurring': 'None',
#    'otherItems': 'None',
#    'incomeTaxExpense': '3031000000',
#    'totalOtherIncomeExpense': '3071000000',
#    'discontinuedOperations': '613000000',
#    'netIncomeFromContinuingOperations': '10913000000',
#    'netIncomeApplicableToCommonShares': '11054000000',
#    'preferredStockAndOtherAdjustments': 'None'},
#   {'fiscalDateEnding': '2018-09-30',
#    'reportedCurrency': 'USD',
#    'totalRevenue': '59434000000',
#    'totalOperatingExpense': '44597000000',
#    'costOfRevenue': '32726000000',
#    'grossProfit': '26708000000',
#    'ebit': '18422000000',
#    'netIncome': '12598000000',
#    'researchAndDevelopment': '0',
#    'effectOfAccountingCharges': 'None',
#    'incomeBeforeTax': '14729000000',
#    'minorityInterest': '5182000000',
#    'sellingGeneralAdministrative': '8860000000',
#    'otherNonOperatingIncome': 'None',
#    'operatingIncome': '14837000000',
#    'otherOperatingExpense': 'None',
#    'interestExpense': '682000000',
#    'taxProvision': '1663000000',
#    'interestIncome': '108000000',
#    'netInterestIncome': '-574000000',
#    'extraordinaryItems': '1700000000',
#    'nonRecurring': 'None',
#    'otherItems': 'None',
#    'incomeTaxExpense': '1663000000',
#    'totalOtherIncomeExpense': '466000000',
#    'discontinuedOperations': '613000000',
#    'netIncomeFromContinuingOperations': '13066000000',
#    'netIncomeApplicableToCommonShares': '12598000000',
#    'preferredStockAndOtherAdjustments': 'None'},
#   {'fiscalDateEnding': '2017-09-30',
#    'reportedCurrency': 'USD',
#    'totalRevenue': '55137000000',
#    'totalOperatingExpense': '41264000000',
#    'costOfRevenue': '30306000000',
#    'grossProfit': '24831000000',
#    'ebit': '17077000000',
#    'netIncome': '8980000000',
#    'researchAndDevelopment': '0',
#    'effectOfAccountingCharges': 'None',
#    'incomeBeforeTax': '13788000000',
#    'minorityInterest': '4837000000',
#    'sellingGeneralAdministrative': '8176000000',
#    'otherNonOperatingIncome': 'None',
#    'operatingIncome': '13873000000',
#    'otherOperatingExpense': '2782000000',
#    'interestExpense': '507000000',
#    'taxProvision': '4422000000',
#    'interestIncome': '122000000',
#    'netInterestIncome': '-385000000',
#    'extraordinaryItems': 'None',
#    'nonRecurring': '98000000',
#    'otherItems': 'None',
#    'incomeTaxExpense': '4422000000',
#    'totalOtherIncomeExpense': '300000000',
#    'discontinuedOperations': '613000000',
#    'netIncomeFromContinuingOperations': '9366000000',
#    'netIncomeApplicableToCommonShares': '8980000000',
#    'preferredStockAndOtherAdjustments': 'None'},
#   {'fiscalDateEnding': '2016-10-01',
#    'reportedCurrency': 'USD',
#    'totalRevenue': '55632000000',
#    'totalOperatingExpense': '41274000000',
#    'costOfRevenue': '29993000000',
#    'grossProfit': '25639000000',
#    'ebit': '17749000000',
#    'netIncome': '9391000000',
#    'researchAndDevelopment': '0',
#    'effectOfAccountingCharges': 'None',
#    'incomeBeforeTax': '14868000000',
#    'minorityInterest': '4058000000',
#    'sellingGeneralAdministrative': '8754000000',
#    'otherNonOperatingIncome': 'None',
#    'operatingIncome': '14358000000',
#    'otherOperatingExpense': '2527000000',
#    'interestExpense': '354000000',
#    'taxProvision': '5078000000',
#    'interestIncome': '94000000',
#    'netInterestIncome': '-260000000',
#    'extraordinaryItems': 'None',
#    'nonRecurring': '156000000',
#    'otherItems': 'None',
#    'incomeTaxExpense': '5078000000',
#    'totalOtherIncomeExpense': '770000000',
#    'discontinuedOperations': '613000000',
#    'netIncomeFromContinuingOperations': '9790000000',
#    'netIncomeApplicableToCommonShares': '9391000000',
#    'preferredStockAndOtherAdjustments': 'None'},
#   {'fiscalDateEnding': '2016-09-30',
#    'reportedCurrency': 'USD',
#    'totalRevenue': '55632000000',
#    'totalOperatingExpense': '41274000000',
#    'costOfRevenue': '29993000000',
#    'grossProfit': '25639000000',
#    'ebit': '17749000000',
#    'netIncome': '9391000000',
#    'researchAndDevelopment': 'None',
#    'effectOfAccountingCharges': 'None',
#    'incomeBeforeTax': '14868000000',
#    'minorityInterest': '4058000000',
#    'sellingGeneralAdministrative': '8754000000',
#    'otherNonOperatingIncome': 'None',
#    'operatingIncome': '14358000000',
#    'otherOperatingExpense': 'None',
#    'interestExpense': '354000000',
#    'taxProvision': '5078000000',
#    'interestIncome': '94000000',
#    'netInterestIncome': '-260000000',
#    'extraordinaryItems': 'None',
#    'nonRecurring': 'None',
#    'otherItems': 'None',
#    'incomeTaxExpense': '5078000000',
#    'totalOtherIncomeExpense': '770000000',
#    'discontinuedOperations': '613000000',
#    'netIncomeFromContinuingOperations': '9790000000',
#    'netIncomeApplicableToCommonShares': '9391000000',
#    'preferredStockAndOtherAdjustments': 'None'}],
#  'quarterlyReports': [{'fiscalDateEnding': '2020-06-30',
#    'reportedCurrency': 'USD',
#    'totalRevenue': '11779000000',
#    'totalOperatingExpense': '11728000000',
#    'costOfRevenue': '7896000000',
#    'grossProfit': '3883000000',
#    'ebit': '-3005000000',
#    'netIncome': '-4721000000',
#    'researchAndDevelopment': 'None',
#    'effectOfAccountingCharges': 'None',
#    'incomeBeforeTax': '-4840000000',
#    'minorityInterest': '13759000000',
#    'sellingGeneralAdministrative': '2455000000',
#    'otherNonOperatingIncome': 'None',
#    'operatingIncome': '51000000',
#    'otherOperatingExpense': 'None',
#    'interestExpense': '456000000',
#    'taxProvision': '-331000000',
#    'interestIncome': '41000000',
#    'netInterestIncome': '-415000000',
#    'extraordinaryItems': 'None',
#    'nonRecurring': 'None',
#    'otherItems': 'None',
#    'incomeTaxExpense': '-331000000',
#    'totalOtherIncomeExpense': '-4476000000',
#    'discontinuedOperations': '-3000000',
#    'netIncomeFromContinuingOperations': '-4509000000',
#    'netIncomeApplicableToCommonShares': '-4721000000',
#    'preferredStockAndOtherAdjustments': 'None'},
#   {'fiscalDateEnding': '2020-03-31',
#    'reportedCurrency': 'USD',
#    'totalRevenue': '18009000000',
#    'totalOperatingExpense': '16639000000',
#    'costOfRevenue': '11918000000',
#    'grossProfit': '6091000000',
#    'ebit': '2758000000',
#    'netIncome': '460000000',
#    'researchAndDevelopment': 'None',
#    'effectOfAccountingCharges': 'None',
#    'incomeBeforeTax': '1060000000',
#    'minorityInterest': '13566000000',
#    'sellingGeneralAdministrative': '3388000000',
#    'otherNonOperatingIncome': 'None',
#    'operatingIncome': '1370000000',
#    'otherOperatingExpense': 'None',
#    'interestExpense': '365000000',
#    'taxProvision': '525000000',
#    'interestIncome': '63000000',
#    'netInterestIncome': '-302000000',
#    'extraordinaryItems': '-15000000',
#    'nonRecurring': 'None',
#    'otherItems': 'None',
#    'incomeTaxExpense': '522000000',
#    'totalOtherIncomeExpense': '-8000000',
#    'discontinuedOperations': '-3000000',
#    'netIncomeFromContinuingOperations': '535000000',
#    'netIncomeApplicableToCommonShares': '460000000',
#    'preferredStockAndOtherAdjustments': 'None'},
#   {'fiscalDateEnding': '2019-12-31',
#    'reportedCurrency': 'USD',
#    'totalRevenue': '20858000000',
#    'totalOperatingExpense': '18017000000',
#    'costOfRevenue': '13016000000',
#    'grossProfit': '7842000000',
#    'ebit': '4292000000',
#    'netIncome': '2107000000',
#    'researchAndDevelopment': 'None',
#    'effectOfAccountingCharges': 'None',
#    'incomeBeforeTax': '2632000000',
#    'minorityInterest': '14045000000',
#    'sellingGeneralAdministrative': '3703000000',
#    'otherNonOperatingIncome': 'None',
#    'operatingIncome': '2841000000',
#    'otherOperatingExpense': 'None',
#    'interestExpense': '362000000',
#    'taxProvision': '459000000',
#    'interestIncome': '76000000',
#    'netInterestIncome': '-286000000',
#    'extraordinaryItems': '-26000000',
#    'nonRecurring': 'None',
#    'otherItems': 'None',
#    'incomeTaxExpense': '459000000',
#    'totalOtherIncomeExpense': '77000000',
#    'discontinuedOperations': '-26000000',
#    'netIncomeFromContinuingOperations': '2173000000',
#    'netIncomeApplicableToCommonShares': '2107000000',
#    'preferredStockAndOtherAdjustments': 'None'},
#   {'fiscalDateEnding': '2019-09-30',
#    'reportedCurrency': 'USD',
#    'totalRevenue': '19100000000',
#    'totalOperatingExpense': '16815000000',
#    'costOfRevenue': '11822000000',
#    'grossProfit': '7278000000',
#    'ebit': '2967000000',
#    'netIncome': '1054000000',
#    'researchAndDevelopment': 'None',
#    'effectOfAccountingCharges': 'None',
#    'incomeBeforeTax': '1258000000',
#    'minorityInterest': '13975000000',
#    'sellingGeneralAdministrative': '3697000000',
#    'otherNonOperatingIncome': 'None',
#    'operatingIncome': '2285000000',
#    'otherOperatingExpense': 'None',
#    'interestExpense': '413000000',
#    'taxProvision': '344000000',
#    'interestIncome': '129000000',
#    'netInterestIncome': '-284000000',
#    'extraordinaryItems': '269000000',
#    'nonRecurring': 'None',
#    'otherItems': 'None',
#    'incomeTaxExpense': '344000000',
#    'totalOtherIncomeExpense': '-743000000',
#    'discontinuedOperations': '269000000',
#    'netIncomeFromContinuingOperations': '914000000',
#    'netIncomeApplicableToCommonShares': '1054000000',
#    'preferredStockAndOtherAdjustments': 'None'},
#   {'fiscalDateEnding': '2019-06-30',
#    'reportedCurrency': 'USD',
#    'totalRevenue': '20245000000',
#    'totalOperatingExpense': '17485000000',
#    'costOfRevenue': '12819000000',
#    'grossProfit': '7426000000',
#    'ebit': '3794000000',
#    'netIncome': '1760000000',
#    'researchAndDevelopment': 'None',
#    'effectOfAccountingCharges': 'None',
#    'incomeBeforeTax': '2018000000',
#    'minorityInterest': '14781000000',
#    'sellingGeneralAdministrative': '3362000000',
#    'otherNonOperatingIncome': 'None',
#    'operatingIncome': '2760000000',
#    'otherOperatingExpense': 'None',
#    'interestExpense': '472000000',
#    'taxProvision': '395000000',
#    'interestIncome': '34000000',
#    'netInterestIncome': '-438000000',
#    'extraordinaryItems': '323000000',
#    'nonRecurring': 'None',
#    'otherItems': 'None',
#    'incomeTaxExpense': '395000000',
#    'totalOtherIncomeExpense': '-304000000',
#    'discontinuedOperations': '323000000',
#    'netIncomeFromContinuingOperations': '1623000000',
#    'netIncomeApplicableToCommonShares': '1760000000',
#    'preferredStockAndOtherAdjustments': 'None'},
#   {'fiscalDateEnding': '2019-03-31',
#    'reportedCurrency': 'USD',
#    'totalRevenue': '14922000000',
#    'totalOperatingExpense': '11531000000',
#    'costOfRevenue': '8376000000',
#    'grossProfit': '6546000000',
#    'ebit': '8263000000',
#    'netIncome': '5452000000',
#    'researchAndDevelopment': 'None',
#    'effectOfAccountingCharges': 'None',
#    'incomeBeforeTax': '7237000000',
#    'minorityInterest': '15504000000',
#    'sellingGeneralAdministrative': '2327000000',
#    'otherNonOperatingIncome': 'None',
#    'operatingIncome': '3391000000',
#    'otherOperatingExpense': 'None',
#    'interestExpense': '198000000',
#    'taxProvision': '1647000000',
#    'interestIncome': '30000000',
#    'netInterestIncome': '-168000000',
#    'extraordinaryItems': '21000000',
#    'nonRecurring': 'None',
#    'otherItems': 'None',
#    'incomeTaxExpense': '1647000000',
#    'totalOtherIncomeExpense': '4014000000',
#    'discontinuedOperations': '21000000',
#    'netIncomeFromContinuingOperations': '5590000000',
#    'netIncomeApplicableToCommonShares': '5452000000',
#    'preferredStockAndOtherAdjustments': 'None'},
#   {'fiscalDateEnding': '2018-12-29',
#    'reportedCurrency': 'USD',
#    'totalRevenue': '15303000000',
#    'totalOperatingExpense': '11885000000',
#    'costOfRevenue': '9001000000',
#    'grossProfit': '6302000000',
#    'ebit': '3418000000',
#    'netIncome': '2788000000',
#    'researchAndDevelopment': 'None',
#    'effectOfAccountingCharges': 'None',
#    'incomeBeforeTax': '3431000000',
#    'minorityInterest': '5201000000',
#    'sellingGeneralAdministrative': '2152000000',
#    'otherNonOperatingIncome': 'None',
#    'operatingIncome': '3418000000',
#    'otherOperatingExpense': 'None',
#    'interestExpense': '-163000000',
#    'taxProvision': 'None',
#    'interestIncome': 'None',
#    'netInterestIncome': 'None',
#    'extraordinaryItems': '34000000',
#    'nonRecurring': 'None',
#    'otherItems': 'None',
#    'incomeTaxExpense': '645000000',
#    'totalOtherIncomeExpense': '13000000',
#    'discontinuedOperations': '21000000',
#    'netIncomeFromContinuingOperations': '2786000000',
#    'netIncomeApplicableToCommonShares': '2788000000',
#    'preferredStockAndOtherAdjustments': 'None'},
#   {'fiscalDateEnding': '2018-09-29',
#    'reportedCurrency': 'USD',
#    'totalRevenue': '14307000000',
#    'totalOperatingExpense': '11224000000',
#    'costOfRevenue': '8108000000',
#    'grossProfit': '6199000000',
#    'ebit': '3083000000',
#    'netIncome': '2322000000',
#    'researchAndDevelopment': '0',
#    'effectOfAccountingCharges': '0',
#    'incomeBeforeTax': '3202000000',
#    'minorityInterest': '5182000000',
#    'sellingGeneralAdministrative': '2322000000',
#    'otherNonOperatingIncome': 'None',
#    'operatingIncome': '3083000000',
#    'otherOperatingExpense': '-33000000',
#    'interestExpense': '-189000000',
#    'taxProvision': 'None',
#    'interestIncome': 'None',
#    'netInterestIncome': 'None',
#    'extraordinaryItems': '0',
#    'nonRecurring': '-6000000',
#    'otherItems': '0',
#    'incomeTaxExpense': '783000000',
#    'totalOtherIncomeExpense': '119000000',
#    'discontinuedOperations': '21000000',
#    'netIncomeFromContinuingOperations': '2419000000',
#    'netIncomeApplicableToCommonShares': '2322000000',
#    'preferredStockAndOtherAdjustments': 'None'},
#   {'fiscalDateEnding': '2018-06-30',
#    'reportedCurrency': 'USD',
#    'totalRevenue': '15228000000',
#    'totalOperatingExpense': '11304000000',
#    'costOfRevenue': '8348000000',
#    'grossProfit': '6880000000',
#    'ebit': '3924000000',
#    'netIncome': '2916000000',
#    'researchAndDevelopment': '0',
#    'effectOfAccountingCharges': '0',
#    'incomeBeforeTax': '3854000000',
#    'minorityInterest': '5120000000',
#    'sellingGeneralAdministrative': '2212000000',
#    'otherNonOperatingIncome': 'None',
#    'operatingIncome': '3924000000',
#    'otherOperatingExpense': '1528000000',
#    'interestExpense': '-175000000',
#    'taxProvision': 'None',
#    'interestIncome': 'None',
#    'netInterestIncome': 'None',
#    'extraordinaryItems': '0',
#    'nonRecurring': '38000000',
#    'otherItems': '0',
#    'incomeTaxExpense': '795000000',
#    'totalOtherIncomeExpense': '-70000000',
#    'discontinuedOperations': '21000000',
#    'netIncomeFromContinuingOperations': '3059000000',
#    'netIncomeApplicableToCommonShares': '2916000000',
#    'preferredStockAndOtherAdjustments': 'None'},
#   {'fiscalDateEnding': '2018-03-31',
#    'reportedCurrency': 'USD',
#    'totalRevenue': '14548000000',
#    'totalOperatingExpense': '10511000000',
#    'costOfRevenue': '7533000000',
#    'grossProfit': '7015000000',
#    'ebit': '4037000000',
#    'netIncome': '2937000000',
#    'researchAndDevelopment': '0',
#    'effectOfAccountingCharges': '0',
#    'incomeBeforeTax': '3928000000',
#    'minorityInterest': '4650000000',
#    'sellingGeneralAdministrative': '2247000000',
#    'otherNonOperatingIncome': 'None',
#    'operatingIncome': '4037000000',
#    'otherOperatingExpense': '-2237000000',
#    'interestExpense': '-172000000',
#    'taxProvision': 'None',
#    'interestIncome': 'None',
#    'netInterestIncome': 'None',
#    'extraordinaryItems': '0',
#    'nonRecurring': '-47000000',
#    'otherItems': '0',
#    'incomeTaxExpense': '813000000',
#    'totalOtherIncomeExpense': '-109000000',
#    'discontinuedOperations': '0',
#    'netIncomeFromContinuingOperations': '3115000000',
#    'netIncomeApplicableToCommonShares': '2937000000',
#    'preferredStockAndOtherAdjustments': 'None'},
#   {'fiscalDateEnding': '2017-12-30',
#    'reportedCurrency': 'USD',
#    'totalRevenue': '15351000000',
#    'totalOperatingExpense': '11558000000',
#    'costOfRevenue': '8737000000',
#    'grossProfit': '6614000000',
#    'ebit': '3793000000',
#    'netIncome': '4423000000',
#    'researchAndDevelopment': '0',
#    'effectOfAccountingCharges': '0',
#    'incomeBeforeTax': '3745000000',
#    'minorityInterest': '50000000',
#    'sellingGeneralAdministrative': '2079000000',
#    'otherNonOperatingIncome': 'None',
#    'operatingIncome': '3793000000',
#    'otherOperatingExpense': '742000000',
#    'interestExpense': '146000000',
#    'taxProvision': 'None',
#    'interestIncome': 'None',
#    'netInterestIncome': 'None',
#    'extraordinaryItems': '0',
#    'nonRecurring': '15000000',
#    'otherItems': '0',
#    'incomeTaxExpense': '-728000000',
#    'totalOtherIncomeExpense': '-48000000',
#    'discontinuedOperations': '0',
#    'netIncomeFromContinuingOperations': '4473000000',
#    'netIncomeApplicableToCommonShares': '4423000000',
#    'preferredStockAndOtherAdjustments': 'None'},
#   {'fiscalDateEnding': '2017-09-30',
#    'reportedCurrency': 'USD',
#    'totalRevenue': '12779000000',
#    'totalOperatingExpense': '30699000000',
#    'costOfRevenue': '7214000000',
#    'grossProfit': '24946000000',
#    'ebit': '10233000000',
#    'netIncome': '1747000000',
#    'researchAndDevelopment': '0',
#    'effectOfAccountingCharges': '0',
#    'incomeBeforeTax': '2694000000',
#    'minorityInterest': '118000000',
#    'sellingGeneralAdministrative': '2228000000',
#    'otherNonOperatingIncome': 'None',
#    'operatingIncome': '2629000000',
#    'otherOperatingExpense': '2038000000',
#    'interestExpense': '137000000',
#    'taxProvision': 'None',
#    'interestIncome': 'None',
#    'netInterestIncome': 'None',
#    'extraordinaryItems': '0',
#    'nonRecurring': '0',
#    'otherItems': '0',
#    'incomeTaxExpense': '829000000',
#    'totalOtherIncomeExpense': '-200000000',
#    'discontinuedOperations': '0',
#    'netIncomeFromContinuingOperations': '6520000000',
#    'netIncomeApplicableToCommonShares': '1747000000',
#    'preferredStockAndOtherAdjustments': 'None'},
#   {'fiscalDateEnding': '2017-06-30',
#    'reportedCurrency': 'USD',
#    'totalRevenue': '14238000000',
#    'totalOperatingExpense': '10450000000',
#    'costOfRevenue': '7717000000',
#    'grossProfit': '0',
#    'ebit': '11392000000',
#    'netIncome': '2366000000',
#    'researchAndDevelopment': '0',
#    'effectOfAccountingCharges': '0',
#    'incomeBeforeTax': '3618000000',
#    'minorityInterest': '108000000',
#    'sellingGeneralAdministrative': '2022000000',
#    'otherNonOperatingIncome': 'None',
#    'operatingIncome': '3788000000',
#    'otherOperatingExpense': '2129000000',
#    'interestExpense': '134000000',
#    'taxProvision': 'None',
#    'interestIncome': 'None',
#    'netInterestIncome': 'None',
#    'extraordinaryItems': '0',
#    'nonRecurring': '294000000',
#    'otherItems': '0',
#    'incomeTaxExpense': '1144000000',
#    'totalOtherIncomeExpense': '0',
#    'discontinuedOperations': '0',
#    'netIncomeFromContinuingOperations': '8164000000',
#    'netIncomeApplicableToCommonShares': '2366000000',
#    'preferredStockAndOtherAdjustments': 'None'},
#   {'fiscalDateEnding': '2017-03-31',
#    'reportedCurrency': 'USD',
#    'totalRevenue': '13336000000',
#    'totalOperatingExpense': '0',
#    'costOfRevenue': '6969000000',
#    'grossProfit': '0',
#    'ebit': '-11461000000',
#    'netIncome': '2388000000',
#    'researchAndDevelopment': '0',
#    'effectOfAccountingCharges': '0',
#    'incomeBeforeTax': '3751000000',
#    'minorityInterest': '151000000',
#    'sellingGeneralAdministrative': '1941000000',
#    'otherNonOperatingIncome': 'None',
#    'operatingIncome': '3750000000',
#    'otherOperatingExpense': '-2072000000',
#    'interestExpense': '115000000',
#    'taxProvision': 'None',
#    'interestIncome': 'None',
#    'netInterestIncome': 'None',
#    'extraordinaryItems': '0',
#    'nonRecurring': '-294000000',
#    'otherItems': '0',
#    'incomeTaxExpense': '1212000000',
#    'totalOtherIncomeExpense': '0',
#    'discontinuedOperations': '0',
#    'netIncomeFromContinuingOperations': '-7915000000',
#    'netIncomeApplicableToCommonShares': '2388000000',
#    'preferredStockAndOtherAdjustments': 'None'},
#   {'fiscalDateEnding': '2016-12-31',
#    'reportedCurrency': 'USD',
#    'totalRevenue': '14784000000',
#    'totalOperatingExpense': '0',
#    'costOfRevenue': '8406000000',
#    'grossProfit': '0',
#    'ebit': '3824000000',
#    'netIncome': '2479000000',
#    'researchAndDevelopment': '0',
#    'effectOfAccountingCharges': '0',
#    'incomeBeforeTax': '3725000000',
#    'minorityInterest': '9000000',
#    'sellingGeneralAdministrative': '1985000000',
#    'otherNonOperatingIncome': 'None',
#    'operatingIncome': '3706000000',
#    'otherOperatingExpense': '687000000',
#    'interestExpense': '121000000',
#    'taxProvision': 'None',
#    'interestIncome': 'None',
#    'netInterestIncome': 'None',
#    'extraordinaryItems': '0',
#    'nonRecurring': '98000000',
#    'otherItems': '0',
#    'incomeTaxExpense': '1237000000',
#    'totalOtherIncomeExpense': '0',
#    'discontinuedOperations': '0',
#    'netIncomeFromContinuingOperations': '2597000000',
#    'netIncomeApplicableToCommonShares': '2479000000',
#    'preferredStockAndOtherAdjustments': 'None'},
#   {'fiscalDateEnding': '2016-09-30',
#    'reportedCurrency': 'USD',
#    'totalRevenue': '13142000000',
#    'totalOperatingExpense': '41145000000',
#    'costOfRevenue': '7323000000',
#    'grossProfit': '25768000000',
#    'ebit': '20500000000',
#    'netIncome': '1771000000',
#    'researchAndDevelopment': '0',
#    'effectOfAccountingCharges': '0',
#    'incomeBeforeTax': '2881000000',
#    'minorityInterest': '121000000',
#    'sellingGeneralAdministrative': '2287000000',
#    'otherNonOperatingIncome': 'None',
#    'operatingIncome': '2843000000',
#    'otherOperatingExpense': '3716000000',
#    'interestExpense': '119000000',
#    'taxProvision': 'None',
#    'interestIncome': 'None',
#    'netInterestIncome': 'None',
#    'extraordinaryItems': '0',
#    'nonRecurring': '244000000',
#    'otherItems': '0',
#    'incomeTaxExpense': '989000000',
#    'totalOtherIncomeExpense': '381000000',
#    'discontinuedOperations': '0',
#    'netIncomeFromContinuingOperations': '13920000000',
#    'netIncomeApplicableToCommonShares': '1771000000',
#    'preferredStockAndOtherAdjustments': 'None'},
#   {'fiscalDateEnding': '2016-07-02',
#    'reportedCurrency': 'USD',
#    'totalRevenue': '14277000000',
#    'totalOperatingExpense': '0',
#    'costOfRevenue': '7201000000',
#    'grossProfit': '0',
#    'ebit': '-9435000000',
#    'netIncome': '2597000000',
#    'researchAndDevelopment': '0',
#    'effectOfAccountingCharges': '0',
#    'incomeBeforeTax': '4183000000',
#    'minorityInterest': '115000000',
#    'sellingGeneralAdministrative': '2305000000',
#    'otherNonOperatingIncome': 'None',
#    'operatingIncome': '4145000000',
#    'otherOperatingExpense': '-1794000000',
#    'interestExpense': '88000000',
#    'taxProvision': 'None',
#    'interestIncome': 'None',
#    'netInterestIncome': 'None',
#    'extraordinaryItems': '0',
#    'nonRecurring': '-132000000',
#    'otherItems': '0',
#    'incomeTaxExpense': '1471000000',
#    'totalOtherIncomeExpense': '0',
#    'discontinuedOperations': '0',
#    'netIncomeFromContinuingOperations': '-6423000000',
#    'netIncomeApplicableToCommonShares': '2597000000',
#    'preferredStockAndOtherAdjustments': 'None'},
#   {'fiscalDateEnding': '2016-04-02',
#    'reportedCurrency': 'USD',
#    'totalRevenue': '12969000000',
#    'totalOperatingExpense': '0',
#    'costOfRevenue': '6717000000',
#    'grossProfit': '0',
#    'ebit': '3422000000',
#    'netIncome': '2143000000',
#    'researchAndDevelopment': '0',
#    'effectOfAccountingCharges': '0',
#    'incomeBeforeTax': '3446000000',
#    'minorityInterest': '133000000',
#    'sellingGeneralAdministrative': '2137000000',
#    'otherNonOperatingIncome': 'None',
#    'operatingIncome': '3510000000',
#    'otherOperatingExpense': '605000000',
#    'interestExpense': '81000000',
#    'taxProvision': 'None',
#    'interestIncome': 'None',
#    'netInterestIncome': 'None',
#    'extraordinaryItems': '0',
#    'nonRecurring': '44000000',
#    'otherItems': '0',
#    'incomeTaxExpense': '1170000000',
#    'totalOtherIncomeExpense': '0',
#    'discontinuedOperations': '0',
#    'netIncomeFromContinuingOperations': '2293000000',
#    'netIncomeApplicableToCommonShares': '2143000000',
#    'preferredStockAndOtherAdjustments': 'None'},
#   {'fiscalDateEnding': '2016-01-02',
#    'reportedCurrency': 'USD',
#    'totalRevenue': '15244000000',
#    'totalOperatingExpense': '0',
#    'costOfRevenue': '8623000000',
#    'grossProfit': '0',
#    'ebit': '0',
#    'netIncome': '2880000000',
#    'researchAndDevelopment': '0',
#    'effectOfAccountingCharges': '0',
#    'incomeBeforeTax': '4358000000',
#    'minorityInterest': '30000000',
#    'sellingGeneralAdministrative': '2025000000',
#    'otherNonOperatingIncome': 'None',
#    'operatingIncome': '3989000000',
#    'otherOperatingExpense': '0',
#    'interestExpense': '66000000',
#    'taxProvision': 'None',
#    'interestIncome': 'None',
#    'netInterestIncome': 'None',
#    'extraordinaryItems': '0',
#    'nonRecurring': '0',
#    'otherItems': '0',
#    'incomeTaxExpense': '1448000000',
#    'totalOtherIncomeExpense': '0',
#    'discontinuedOperations': '0',
#    'netIncomeFromContinuingOperations': '0',
#    'netIncomeApplicableToCommonShares': '2880000000',
#    'preferredStockAndOtherAdjustments': 'None'},
#   {'fiscalDateEnding': '2015-10-03',
#    'reportedCurrency': 'USD',
#    'totalRevenue': '13512000000',
#    'totalOperatingExpense': '39241000000',
#    'costOfRevenue': '7355000000',
#    'grossProfit': '24101000000',
#    'ebit': '13224000000',
#    'netIncome': '1609000000',
#    'researchAndDevelopment': '0',
#    'effectOfAccountingCharges': '0',
#    'incomeBeforeTax': '3224000000',
#    'minorityInterest': '132000000',
#    'sellingGeneralAdministrative': '2406000000',
#    'otherNonOperatingIncome': 'None',
#    'operatingIncome': '3148000000',
#    'otherOperatingExpense': '2354000000',
#    'interestExpense': '68000000',
#    'taxProvision': 'None',
#    'interestIncome': 'None',
#    'netInterestIncome': 'None',
#    'extraordinaryItems': '0',
#    'nonRecurring': '53000000',
#    'otherItems': '0',
#    'incomeTaxExpense': '1483000000',
#    'totalOtherIncomeExpense': '644000000',
#    'discontinuedOperations': '0',
#    'netIncomeFromContinuingOperations': '8852000000',
#    'netIncomeApplicableToCommonShares': '1609000000',
#    'preferredStockAndOtherAdjustments': 'None'}]}

# %%
dis_annual_balance_sheet_statement_response.json()
# Out:
# {'symbol': 'DIS',
#  'annualReports': [{'fiscalDateEnding': '2019-09-30',
#    'reportedCurrency': 'USD',
#    'totalAssets': '193984000000',
#    'intangibleAssets': '23215000000',
#    'earningAssets': 'None',
#    'otherCurrentAssets': '979000000',
#    'totalLiabilities': '100095000000',
#    'totalShareholderEquity': '88877000000',
#    'deferredLongTermLiabilities': 'None',
#    'otherCurrentLiabilities': '5691000000',
#    'commonStock': '53907000000',
#    'retainedEarnings': '42494000000',
#    'otherLiabilities': '21516000000',
#    'goodwill': '80293000000',
#    'otherAssets': '27525000000',
#    'cash': '5418000000',
#    'totalCurrentLiabilities': '31341000000',
#    'shortTermDebt': '8857000000',
#    'currentLongTermDebt': '8857000000',
#    'otherShareholderEquity': '-6617000000',
#    'propertyPlantEquipment': '31603000000',
#    'totalCurrentAssets': '28124000000',
#    'longTermInvestments': '3224000000',
#    'netTangibleAssets': '-14631000000',
#    'shortTermInvestments': 'None',
#    'netReceivables': '12882000000',
#    'longTermDebt': '38129000000',
#    'inventory': '1649000000',
#    'accountsPayable': '13778000000',
#    'totalPermanentEquity': 'None',
#    'additionalPaidInCapital': 'None',
#    'commonStockTotalEquity': 'None',
#    'preferredStockTotalEquity': 'None',
#    'retainedEarningsTotalEquity': 'None',
#    'treasuryStock': '-907000000',
#    'accumulatedAmortization': 'None',
#    'otherNonCurrrentAssets': '4715000000',
#    'deferredLongTermAssetCharges': 'None',
#    'totalNonCurrentAssets': '165860000000',
#    'capitalLeaseObligations': 'None',
#    'totalLongTermDebt': '38129000000',
#    'otherNonCurrentLiabilities': '8977000000',
#    'totalNonCurrentLiabilities': '68754000000',
#    'negativeGoodwill': 'None',
#    'warrants': 'None',
#    'preferredStockRedeemable': 'None',
#    'capitalSurplus': 'None',
#    'liabilitiesAndShareholderEquity': 'None',
#    'cashAndShortTermInvestments': '5418000000',
#    'accumulatedDepreciation': 'None',
#    'commonStockSharesOutstanding': '1666000000'},
#   {'fiscalDateEnding': '2018-09-30',
#    'reportedCurrency': 'USD',
#    'totalAssets': '98598000000',
#    'intangibleAssets': '6812000000',
#    'earningAssets': 'None',
#    'otherCurrentAssets': '159000000',
#    'totalLiabilities': '45766000000',
#    'totalShareholderEquity': '48773000000',
#    'deferredLongTermLiabilities': '0',
#    'otherCurrentLiabilities': '5378000000',
#    'commonStock': '36779000000',
#    'retainedEarnings': '82679000000',
#    'otherLiabilities': '9699000000',
#    'goodwill': '31269000000',
#    'otherAssets': '11253000000',
#    'cash': '4150000000',
#    'totalCurrentLiabilities': '17860000000',
#    'shortTermDebt': '3790000000',
#    'currentLongTermDebt': '3790000000',
#    'otherShareholderEquity': '-3097000000',
#    'propertyPlantEquipment': '29540000000',
#    'totalCurrentAssets': '16825000000',
#    'longTermInvestments': '2899000000',
#    'netTangibleAssets': '10692000000',
#    'shortTermInvestments': '1000000',
#    'netReceivables': '8268000000',
#    'longTermDebt': '17084000000',
#    'inventory': '1392000000',
#    'accountsPayable': '6503000000',
#    'totalPermanentEquity': '52832000000',
#    'additionalPaidInCapital': '0',
#    'commonStockTotalEquity': '36779000000',
#    'preferredStockTotalEquity': '0',
#    'retainedEarningsTotalEquity': '82679000000',
#    'treasuryStock': '-67588000000',
#    'accumulatedAmortization': 'None',
#    'otherNonCurrrentAssets': '518000000',
#    'deferredLongTermAssetCharges': 'None',
#    'totalNonCurrentAssets': '81773000000',
#    'capitalLeaseObligations': 'None',
#    'totalLongTermDebt': '17084000000',
#    'otherNonCurrentLiabilities': '3878000000',
#    'totalNonCurrentLiabilities': '27906000000',
#    'negativeGoodwill': 'None',
#    'warrants': 'None',
#    'preferredStockRedeemable': 'None',
#    'capitalSurplus': 'None',
#    'liabilitiesAndShareholderEquity': 'None',
#    'cashAndShortTermInvestments': '4150000000',
#    'accumulatedDepreciation': 'None',
#    'commonStockSharesOutstanding': '1507000000'},
#   {'fiscalDateEnding': '2017-09-30',
#    'reportedCurrency': 'USD',
#    'totalAssets': '95789000000',
#    'intangibleAssets': '6995000000',
#    'earningAssets': 'None',
#    'otherCurrentAssets': '143000000',
#    'totalLiabilities': '50785000000',
#    'totalShareholderEquity': '41315000000',
#    'deferredLongTermLiabilities': '0',
#    'otherCurrentLiabilities': '5299000000',
#    'commonStock': '36248000000',
#    'retainedEarnings': '72606000000',
#    'otherLiabilities': '10923000000',
#    'goodwill': '31426000000',
#    'otherAssets': '9871000000',
#    'cash': '4017000000',
#    'totalCurrentLiabilities': '19595000000',
#    'shortTermDebt': '6172000000',
#    'currentLongTermDebt': '6172000000',
#    'otherShareholderEquity': '-3528000000',
#    'propertyPlantEquipment': '28406000000',
#    'totalCurrentAssets': '15889000000',
#    'longTermInvestments': '3202000000',
#    'netTangibleAssets': '2894000000',
#    'shortTermInvestments': '26000000',
#    'netReceivables': '8013000000',
#    'longTermDebt': '19119000000',
#    'inventory': '1373000000',
#    'accountsPayable': '6490000000',
#    'totalPermanentEquity': '45004000000',
#    'additionalPaidInCapital': '0',
#    'commonStockTotalEquity': '36248000000',
#    'preferredStockTotalEquity': '0',
#    'retainedEarningsTotalEquity': '72606000000',
#    'treasuryStock': '-64011000000',
#    'accumulatedAmortization': 'None',
#    'otherNonCurrrentAssets': '469000000',
#    'deferredLongTermAssetCharges': 'None',
#    'totalNonCurrentAssets': '79900000000',
#    'capitalLeaseObligations': 'None',
#    'totalLongTermDebt': '19119000000',
#    'otherNonCurrentLiabilities': '3162000000',
#    'totalNonCurrentLiabilities': '31190000000',
#    'negativeGoodwill': 'None',
#    'warrants': 'None',
#    'preferredStockRedeemable': 'None',
#    'capitalSurplus': 'None',
#    'liabilitiesAndShareholderEquity': 'None',
#    'cashAndShortTermInvestments': '4017000000',
#    'accumulatedDepreciation': 'None',
#    'commonStockSharesOutstanding': '1578000000'},
#   {'fiscalDateEnding': '2016-10-01',
#    'reportedCurrency': 'USD',
#    'totalAssets': '92033000000',
#    'intangibleAssets': '6949000000',
#    'earningAssets': 'None',
#    'otherCurrentAssets': '244000000',
#    'totalLiabilities': '44710000000',
#    'totalShareholderEquity': '43265000000',
#    'deferredLongTermLiabilities': '0',
#    'otherCurrentLiabilities': '4548000000',
#    'commonStock': '35859000000',
#    'retainedEarnings': '66088000000',
#    'otherLiabilities': '11385000000',
#    'goodwill': '27810000000',
#    'otherAssets': '8701000000',
#    'cash': '4610000000',
#    'totalCurrentLiabilities': '16842000000',
#    'shortTermDebt': '3687000000',
#    'currentLongTermDebt': '3687000000',
#    'otherShareholderEquity': '-3979000000',
#    'propertyPlantEquipment': '27349000000',
#    'totalCurrentAssets': '16966000000',
#    'longTermInvestments': '4280000000',
#    'netTangibleAssets': '8506000000',
#    'shortTermInvestments': '0',
#    'netReceivables': '8458000000',
#    'longTermDebt': '16483000000',
#    'inventory': '1390000000',
#    'accountsPayable': '6860000000',
#    'totalPermanentEquity': '47323000000',
#    'additionalPaidInCapital': '0',
#    'commonStockTotalEquity': '35859000000',
#    'preferredStockTotalEquity': '0',
#    'retainedEarningsTotalEquity': '66088000000',
#    'treasuryStock': '-54703000000',
#    'accumulatedAmortization': 'None',
#    'otherNonCurrrentAssets': '460000000',
#    'deferredLongTermAssetCharges': 'None',
#    'totalNonCurrentAssets': '75067000000',
#    'capitalLeaseObligations': 'None',
#    'totalLongTermDebt': '16483000000',
#    'otherNonCurrentLiabilities': '2522000000',
#    'totalNonCurrentLiabilities': '27868000000',
#    'negativeGoodwill': 'None',
#    'warrants': 'None',
#    'preferredStockRedeemable': 'None',
#    'capitalSurplus': 'None',
#    'liabilitiesAndShareholderEquity': 'None',
#    'cashAndShortTermInvestments': '4610000000',
#    'accumulatedDepreciation': 'None',
#    'commonStockSharesOutstanding': '1639000000'},
#   {'fiscalDateEnding': '2016-09-30',
#    'reportedCurrency': 'USD',
#    'totalAssets': '92033000000',
#    'intangibleAssets': '6949000000',
#    'earningAssets': 'None',
#    'otherCurrentAssets': '244000000',
#    'totalLiabilities': '44710000000',
#    'totalShareholderEquity': '43265000000',
#    'deferredLongTermLiabilities': 'None',
#    'otherCurrentLiabilities': 'None',
#    'commonStock': '35859000000',
#    'retainedEarnings': '66088000000',
#    'otherLiabilities': '11385000000',
#    'goodwill': '27810000000',
#    'otherAssets': '8701000000',
#    'cash': '4610000000',
#    'totalCurrentLiabilities': '16842000000',
#    'shortTermDebt': 'None',
#    'currentLongTermDebt': '3687000000',
#    'otherShareholderEquity': '-3979000000',
#    'propertyPlantEquipment': '27349000000',
#    'totalCurrentAssets': '16966000000',
#    'longTermInvestments': '4280000000',
#    'netTangibleAssets': '8506000000',
#    'shortTermInvestments': 'None',
#    'netReceivables': '8458000000',
#    'longTermDebt': '16483000000',
#    'inventory': '1390000000',
#    'accountsPayable': '6860000000',
#    'totalPermanentEquity': 'None',
#    'additionalPaidInCapital': 'None',
#    'commonStockTotalEquity': 'None',
#    'preferredStockTotalEquity': 'None',
#    'retainedEarningsTotalEquity': 'None',
#    'treasuryStock': 'None',
#    'accumulatedAmortization': 'None',
#    'otherNonCurrrentAssets': '460000000',
#    'deferredLongTermAssetCharges': 'None',
#    'totalNonCurrentAssets': '75067000000',
#    'capitalLeaseObligations': 'None',
#    'totalLongTermDebt': 'None',
#    'otherNonCurrentLiabilities': '2522000000',
#    'totalNonCurrentLiabilities': '27868000000',
#    'negativeGoodwill': 'None',
#    'warrants': 'None',
#    'preferredStockRedeemable': 'None',
#    'capitalSurplus': 'None',
#    'liabilitiesAndShareholderEquity': 'None',
#    'cashAndShortTermInvestments': 'None',
#    'accumulatedDepreciation': 'None',
#    'commonStockSharesOutstanding': 'None'}],
#  'quarterlyReports': [{'fiscalDateEnding': '2020-06-30',
#    'reportedCurrency': 'USD',
#    'totalAssets': '207649000000',
#    'intangibleAssets': '19589000000',
#    'earningAssets': 'None',
#    'otherCurrentAssets': '899000000',
#    'totalLiabilities': '117186000000',
#    'totalShareholderEquity': '85866000000',
#    'deferredLongTermLiabilities': 'None',
#    'otherCurrentLiabilities': 'None',
#    'commonStock': '54386000000',
#    'retainedEarnings': '39004000000',
#    'otherLiabilities': '19860000000',
#    'goodwill': '77233000000',
#    'otherAssets': '29749000000',
#    'cash': '23115000000',
#    'totalCurrentLiabilities': '30917000000',
#    'shortTermDebt': 'None',
#    'currentLongTermDebt': '10224000000',
#    'otherShareholderEquity': '-6617000000',
#    'propertyPlantEquipment': '36137000000',
#    'totalCurrentAssets': '41330000000',
#    'longTermInvestments': '3611000000',
#    'netTangibleAssets': '-10956000000',
#    'shortTermInvestments': 'None',
#    'netReceivables': '12622000000',
#    'longTermDebt': '54197000000',
#    'inventory': '1559000000',
#    'accountsPayable': 'None',
#    'totalPermanentEquity': 'None',
#    'additionalPaidInCapital': 'None',
#    'commonStockTotalEquity': 'None',
#    'preferredStockTotalEquity': 'None',
#    'retainedEarningsTotalEquity': 'None',
#    'treasuryStock': 'None',
#    'accumulatedAmortization': 'None',
#    'otherNonCurrrentAssets': '8435000000',
#    'deferredLongTermAssetCharges': 'None',
#    'totalNonCurrentAssets': '166319000000',
#    'capitalLeaseObligations': 'None',
#    'totalLongTermDebt': 'None',
#    'otherNonCurrentLiabilities': '15855000000',
#    'totalNonCurrentLiabilities': '86269000000',
#    'negativeGoodwill': 'None',
#    'warrants': 'None',
#    'preferredStockRedeemable': 'None',
#    'capitalSurplus': 'None',
#    'liabilitiesAndShareholderEquity': 'None',
#    'cashAndShortTermInvestments': 'None',
#    'accumulatedDepreciation': 'None',
#    'commonStockSharesOutstanding': 'None'},
#   {'fiscalDateEnding': '2020-03-31',
#    'reportedCurrency': 'USD',
#    'totalAssets': '206294000000',
#    'intangibleAssets': '22037000000',
#    'earningAssets': 'None',
#    'otherCurrentAssets': '1003000000',
#    'totalLiabilities': '111417000000',
#    'totalShareholderEquity': '90407000000',
#    'deferredLongTermLiabilities': 'None',
#    'otherCurrentLiabilities': 'None',
#    'commonStock': '54230000000',
#    'retainedEarnings': '43721000000',
#    'otherLiabilities': '20827000000',
#    'goodwill': '80320000000',
#    'otherAssets': '30768000000',
#    'cash': '14339000000',
#    'totalCurrentLiabilities': '35473000000',
#    'shortTermDebt': 'None',
#    'currentLongTermDebt': '12676000000',
#    'otherShareholderEquity': '-6637000000',
#    'propertyPlantEquipment': '36715000000',
#    'totalCurrentAssets': '33274000000',
#    'longTermInvestments': '3180000000',
#    'netTangibleAssets': '-11950000000',
#    'shortTermInvestments': 'None',
#    'netReceivables': '14532000000',
#    'longTermDebt': '42770000000',
#    'inventory': '1531000000',
#    'accountsPayable': 'None',
#    'totalPermanentEquity': 'None',
#    'additionalPaidInCapital': 'None',
#    'commonStockTotalEquity': 'None',
#    'preferredStockTotalEquity': 'None',
#    'retainedEarningsTotalEquity': 'None',
#    'treasuryStock': '-907000000',
#    'accumulatedAmortization': 'None',
#    'otherNonCurrrentAssets': '8575000000',
#    'deferredLongTermAssetCharges': 'None',
#    'totalNonCurrentAssets': '173020000000',
#    'capitalLeaseObligations': 'None',
#    'totalLongTermDebt': '43052000000',
#    'otherNonCurrentLiabilities': '16113000000',
#    'totalNonCurrentLiabilities': '75944000000',
#    'negativeGoodwill': 'None',
#    'warrants': 'None',
#    'preferredStockRedeemable': 'None',
#    'capitalSurplus': 'None',
#    'liabilitiesAndShareholderEquity': 'None',
#    'cashAndShortTermInvestments': '14339000000',
#    'accumulatedDepreciation': 'None',
#    'commonStockSharesOutstanding': '1816000000'},
#   {'fiscalDateEnding': '2019-12-31',
#    'reportedCurrency': 'USD',
#    'totalAssets': '200948000000',
#    'intangibleAssets': '22669000000',
#    'earningAssets': 'None',
#    'otherCurrentAssets': '938000000',
#    'totalLiabilities': '106175000000',
#    'totalShareholderEquity': '89757000000',
#    'deferredLongTermLiabilities': 'None',
#    'otherCurrentLiabilities': '5024000000',
#    'commonStock': '53995000000',
#    'retainedEarnings': '43202000000',
#    'otherLiabilities': '21270000000',
#    'goodwill': '80314000000',
#    'otherAssets': '31374000000',
#    'cash': '6833000000',
#    'totalCurrentLiabilities': '34797000000',
#    'shortTermDebt': '10018000000',
#    'currentLongTermDebt': '10018000000',
#    'otherShareholderEquity': '-6533000000',
#    'propertyPlantEquipment': '35503000000',
#    'totalCurrentAssets': '27776000000',
#    'longTermInvestments': '3312000000',
#    'netTangibleAssets': '-13226000000',
#    'shortTermInvestments': 'None',
#    'netReceivables': '17100000000',
#    'longTermDebt': '38057000000',
#    'inventory': '1571000000',
#    'accountsPayable': '18920000000',
#    'totalPermanentEquity': 'None',
#    'additionalPaidInCapital': 'None',
#    'commonStockTotalEquity': 'None',
#    'preferredStockTotalEquity': 'None',
#    'retainedEarningsTotalEquity': 'None',
#    'treasuryStock': '-907000000',
#    'accumulatedAmortization': 'None',
#    'otherNonCurrrentAssets': '8443000000',
#    'deferredLongTermAssetCharges': 'None',
#    'totalNonCurrentAssets': '173172000000',
#    'capitalLeaseObligations': 'None',
#    'totalLongTermDebt': '38309000000',
#    'otherNonCurrentLiabilities': '15928000000',
#    'totalNonCurrentLiabilities': '71378000000',
#    'negativeGoodwill': 'None',
#    'warrants': 'None',
#    'preferredStockRedeemable': 'None',
#    'capitalSurplus': 'None',
#    'liabilitiesAndShareholderEquity': 'None',
#    'cashAndShortTermInvestments': '6833000000',
#    'accumulatedDepreciation': 'None',
#    'commonStockSharesOutstanding': '1817000000'},
#   {'fiscalDateEnding': '2019-09-30',
#    'reportedCurrency': 'USD',
#    'totalAssets': '193984000000',
#    'intangibleAssets': '23215000000',
#    'earningAssets': 'None',
#    'otherCurrentAssets': '979000000',
#    'totalLiabilities': '100095000000',
#    'totalShareholderEquity': '88877000000',
#    'deferredLongTermLiabilities': 'None',
#    'otherCurrentLiabilities': '5691000000',
#    'commonStock': '53907000000',
#    'retainedEarnings': '42494000000',
#    'otherLiabilities': '21516000000',
#    'goodwill': '80293000000',
#    'otherAssets': '27525000000',
#    'cash': '5418000000',
#    'totalCurrentLiabilities': '31341000000',
#    'shortTermDebt': '8857000000',
#    'currentLongTermDebt': '8857000000',
#    'otherShareholderEquity': '-6617000000',
#    'propertyPlantEquipment': '31603000000',
#    'totalCurrentAssets': '28124000000',
#    'longTermInvestments': '3224000000',
#    'netTangibleAssets': '-14631000000',
#    'shortTermInvestments': 'None',
#    'netReceivables': '12882000000',
#    'longTermDebt': '38129000000',
#    'inventory': '1649000000',
#    'accountsPayable': '13778000000',
#    'totalPermanentEquity': 'None',
#    'additionalPaidInCapital': 'None',
#    'commonStockTotalEquity': 'None',
#    'preferredStockTotalEquity': 'None',
#    'retainedEarningsTotalEquity': 'None',
#    'treasuryStock': '-907000000',
#    'accumulatedAmortization': 'None',
#    'otherNonCurrrentAssets': '4715000000',
#    'deferredLongTermAssetCharges': 'None',
#    'totalNonCurrentAssets': '165860000000',
#    'capitalLeaseObligations': 'None',
#    'totalLongTermDebt': '38129000000',
#    'otherNonCurrentLiabilities': '8977000000',
#    'totalNonCurrentLiabilities': '68754000000',
#    'negativeGoodwill': 'None',
#    'warrants': 'None',
#    'preferredStockRedeemable': 'None',
#    'capitalSurplus': 'None',
#    'liabilitiesAndShareholderEquity': 'None',
#    'cashAndShortTermInvestments': '5418000000',
#    'accumulatedDepreciation': 'None',
#    'commonStockSharesOutstanding': '1666000000'},
#   {'fiscalDateEnding': '2019-06-30',
#    'reportedCurrency': 'USD',
#    'totalAssets': '209475000000',
#    'intangibleAssets': '25114000000',
#    'earningAssets': 'None',
#    'otherCurrentAssets': '1034000000',
#    'totalLiabilities': '113119000000',
#    'totalShareholderEquity': '90472000000',
#    'deferredLongTermLiabilities': 'None',
#    'otherCurrentLiabilities': '293000000',
#    'commonStock': '53718000000',
#    'retainedEarnings': '41382000000',
#    'otherLiabilities': '23318000000',
#    'goodwill': '77801000000',
#    'otherAssets': '39926000000',
#    'cash': '6728000000',
#    'totalCurrentLiabilities': '44593000000',
#    'shortTermDebt': '21923000000',
#    'currentLongTermDebt': '21923000000',
#    'otherShareholderEquity': '-3721000000',
#    'propertyPlantEquipment': '31392000000',
#    'totalCurrentAssets': '31370000000',
#    'longTermInvestments': '3872000000',
#    'netTangibleAssets': '-12443000000',
#    'shortTermInvestments': 'None',
#    'netReceivables': '15938000000',
#    'longTermDebt': '36311000000',
#    'inventory': '1516000000',
#    'accountsPayable': '17647000000',
#    'totalPermanentEquity': 'None',
#    'additionalPaidInCapital': 'None',
#    'commonStockTotalEquity': 'None',
#    'preferredStockTotalEquity': 'None',
#    'retainedEarningsTotalEquity': 'None',
#    'treasuryStock': '-907000000',
#    'accumulatedAmortization': 'None',
#    'otherNonCurrrentAssets': '17374000000',
#    'deferredLongTermAssetCharges': 'None',
#    'totalNonCurrentAssets': '178105000000',
#    'capitalLeaseObligations': 'None',
#    'totalLongTermDebt': '36311000000',
#    'otherNonCurrentLiabilities': '10561000000',
#    'totalNonCurrentLiabilities': '68526000000',
#    'negativeGoodwill': 'None',
#    'warrants': 'None',
#    'preferredStockRedeemable': 'None',
#    'capitalSurplus': 'None',
#    'liabilitiesAndShareholderEquity': 'None',
#    'cashAndShortTermInvestments': '6728000000',
#    'accumulatedDepreciation': 'None',
#    'commonStockSharesOutstanding': '1814000000'},
#   {'fiscalDateEnding': '2019-03-31',
#    'reportedCurrency': 'USD',
#    'totalAssets': '214342000000',
#    'intangibleAssets': '26985000000',
#    'earningAssets': 'None',
#    'otherCurrentAssets': '1248000000',
#    'totalLiabilities': '110003000000',
#    'totalShareholderEquity': '89938000000',
#    'deferredLongTermLiabilities': 'None',
#    'otherCurrentLiabilities': '434000000',
#    'commonStock': '53419000000',
#    'retainedEarnings': '41212000000',
#    'otherLiabilities': '26721000000',
#    'goodwill': '75057000000',
#    'otherAssets': '42926000000',
#    'cash': '10108000000',
#    'totalCurrentLiabilities': '44376000000',
#    'shortTermDebt': '19158000000',
#    'currentLongTermDebt': '19158000000',
#    'otherShareholderEquity': '-3786000000',
#    'propertyPlantEquipment': '31017000000',
#    'totalCurrentAssets': '34277000000',
#    'longTermInvestments': '4080000000',
#    'netTangibleAssets': '-12104000000',
#    'shortTermInvestments': 'None',
#    'netReceivables': '14593000000',
#    'longTermDebt': '37803000000',
#    'inventory': '1445000000',
#    'accountsPayable': '20503000000',
#    'totalPermanentEquity': 'None',
#    'additionalPaidInCapital': 'None',
#    'commonStockTotalEquity': 'None',
#    'preferredStockTotalEquity': 'None',
#    'retainedEarningsTotalEquity': 'None',
#    'treasuryStock': '-907000000',
#    'accumulatedAmortization': 'None',
#    'otherNonCurrrentAssets': '18573000000',
#    'deferredLongTermAssetCharges': 'None',
#    'totalNonCurrentAssets': '180065000000',
#    'capitalLeaseObligations': 'None',
#    'totalLongTermDebt': '37803000000',
#    'otherNonCurrentLiabilities': '12854000000',
#    'totalNonCurrentLiabilities': '65627000000',
#    'negativeGoodwill': 'None',
#    'warrants': 'None',
#    'preferredStockRedeemable': 'None',
#    'capitalSurplus': 'None',
#    'liabilitiesAndShareholderEquity': 'None',
#    'cashAndShortTermInvestments': '10208000000',
#    'accumulatedDepreciation': 'None',
#    'commonStockSharesOutstanding': '1537000000'},
#   {'fiscalDateEnding': '2018-12-29',
#    'reportedCurrency': 'USD',
#    'totalAssets': '99941000000',
#    'intangibleAssets': '6747000000',
#    'earningAssets': 'None',
#    'otherCurrentAssets': '778000000',
#    'totalLiabilities': '44424000000',
#    'totalShareholderEquity': '50316000000',
#    'deferredLongTermLiabilities': 'None',
#    'otherCurrentLiabilities': '3434000000',
#    'commonStock': '36799000000',
#    'retainedEarnings': '84887000000',
#    'otherLiabilities': '9629000000',
#    'goodwill': '31289000000',
#    'otherAssets': '11601000000',
#    'cash': '4455000000',
#    'totalCurrentLiabilities': '17619000000',
#    'shortTermDebt': '2790000000',
#    'currentLongTermDebt': '2790000000',
#    'otherShareholderEquity': '-3782000000',
#    'propertyPlantEquipment': '29797000000',
#    'totalCurrentAssets': '17537000000',
#    'longTermInvestments': '2970000000',
#    'netTangibleAssets': '12280000000',
#    'shortTermInvestments': 'None',
#    'netReceivables': '10123000000',
#    'longTermDebt': '17176000000',
#    'inventory': '2181000000',
#    'accountsPayable': '10696000000',
#    'totalPermanentEquity': 'None',
#    'additionalPaidInCapital': 'None',
#    'commonStockTotalEquity': 'None',
#    'preferredStockTotalEquity': 'None',
#    'retainedEarningsTotalEquity': 'None',
#    'treasuryStock': '-67588000000',
#    'accumulatedAmortization': 'None',
#    'otherNonCurrrentAssets': 'None',
#    'deferredLongTermAssetCharges': 'None',
#    'totalNonCurrentAssets': 'None',
#    'capitalLeaseObligations': 'None',
#    'totalLongTermDebt': '17176000000',
#    'otherNonCurrentLiabilities': 'None',
#    'totalNonCurrentLiabilities': 'None',
#    'negativeGoodwill': 'None',
#    'warrants': 'None',
#    'preferredStockRedeemable': 'None',
#    'capitalSurplus': 'None',
#    'liabilitiesAndShareholderEquity': 'None',
#    'cashAndShortTermInvestments': '4455000000',
#    'accumulatedDepreciation': 'None',
#    'commonStockSharesOutstanding': '1498000000'},
#   {'fiscalDateEnding': '2018-09-29',
#    'reportedCurrency': 'USD',
#    'totalAssets': '98598000000',
#    'intangibleAssets': '6812000000',
#    'earningAssets': 'None',
#    'otherCurrentAssets': '159000000',
#    'totalLiabilities': '44643000000',
#    'totalShareholderEquity': '48773000000',
#    'deferredLongTermLiabilities': '0',
#    'otherCurrentLiabilities': '5378000000',
#    'commonStock': '36779000000',
#    'retainedEarnings': '82679000000',
#    'otherLiabilities': '9699000000',
#    'goodwill': '31269000000',
#    'otherAssets': '11253000000',
#    'cash': '4150000000',
#    'totalCurrentLiabilities': '17860000000',
#    'shortTermDebt': '2785000000',
#    'currentLongTermDebt': '2785000000',
#    'otherShareholderEquity': '-3097000000',
#    'propertyPlantEquipment': '29540000000',
#    'totalCurrentAssets': '16825000000',
#    'longTermInvestments': '2899000000',
#    'netTangibleAssets': '10692000000',
#    'shortTermInvestments': '1000000',
#    'netReceivables': '9334000000',
#    'longTermDebt': '17084000000',
#    'inventory': '2706000000',
#    'accountsPayable': '6503000000',
#    'totalPermanentEquity': '52832000000',
#    'additionalPaidInCapital': '0',
#    'commonStockTotalEquity': '36779000000',
#    'preferredStockTotalEquity': '0',
#    'retainedEarningsTotalEquity': '82679000000',
#    'treasuryStock': '-67588000000',
#    'accumulatedAmortization': 'None',
#    'otherNonCurrrentAssets': 'None',
#    'deferredLongTermAssetCharges': 'None',
#    'totalNonCurrentAssets': 'None',
#    'capitalLeaseObligations': 'None',
#    'totalLongTermDebt': 'None',
#    'otherNonCurrentLiabilities': 'None',
#    'totalNonCurrentLiabilities': 'None',
#    'negativeGoodwill': 'None',
#    'warrants': 'None',
#    'preferredStockRedeemable': 'None',
#    'capitalSurplus': 'None',
#    'liabilitiesAndShareholderEquity': 'None',
#    'cashAndShortTermInvestments': 'None',
#    'accumulatedDepreciation': 'None',
#    'commonStockSharesOutstanding': '1507000000'},
#   {'fiscalDateEnding': '2018-06-30',
#    'reportedCurrency': 'USD',
#    'totalAssets': '98792000000',
#    'intangibleAssets': '6892000000',
#    'earningAssets': 'None',
#    'otherCurrentAssets': '769000000',
#    'totalLiabilities': '47584000000',
#    'totalShareholderEquity': '46088000000',
#    'deferredLongTermLiabilities': '0',
#    'otherCurrentLiabilities': '4459000000',
#    'commonStock': '36574000000',
#    'retainedEarnings': '80364000000',
#    'otherLiabilities': '9689000000',
#    'goodwill': '31306000000',
#    'otherAssets': '10337000000',
#    'cash': '4326000000',
#    'totalCurrentLiabilities': '20214000000',
#    'shortTermDebt': '2759000000',
#    'currentLongTermDebt': '2759000000',
#    'otherShareholderEquity': '-3262000000',
#    'propertyPlantEquipment': '29373000000',
#    'totalCurrentAssets': '17729000000',
#    'longTermInvestments': '3155000000',
#    'netTangibleAssets': '7890000000',
#    'shortTermInvestments': '1000000',
#    'netReceivables': '10071000000',
#    'longTermDebt': '17681000000',
#    'inventory': '2563000000',
#    'accountsPayable': '9763000000',
#    'totalPermanentEquity': '50071000000',
#    'additionalPaidInCapital': '0',
#    'commonStockTotalEquity': '0',
#    'preferredStockTotalEquity': '0',
#    'retainedEarningsTotalEquity': '0',
#    'treasuryStock': '-67588000000',
#    'accumulatedAmortization': 'None',
#    'otherNonCurrrentAssets': 'None',
#    'deferredLongTermAssetCharges': 'None',
#    'totalNonCurrentAssets': 'None',
#    'capitalLeaseObligations': 'None',
#    'totalLongTermDebt': 'None',
#    'otherNonCurrentLiabilities': 'None',
#    'totalNonCurrentLiabilities': 'None',
#    'negativeGoodwill': 'None',
#    'warrants': 'None',
#    'preferredStockRedeemable': 'None',
#    'capitalSurplus': 'None',
#    'liabilitiesAndShareholderEquity': 'None',
#    'cashAndShortTermInvestments': 'None',
#    'accumulatedDepreciation': 'None',
#    'commonStockSharesOutstanding': '1498000000'},
#   {'fiscalDateEnding': '2018-03-31',
#    'reportedCurrency': 'USD',
#    'totalAssets': '97943000000',
#    'intangibleAssets': '6962000000',
#    'earningAssets': 'None',
#    'otherCurrentAssets': '536000000',
#    'totalLiabilities': '48142000000',
#    'totalShareholderEquity': '45151000000',
#    'deferredLongTermLiabilities': '0',
#    'otherCurrentLiabilities': '4788000000',
#    'commonStock': '36411000000',
#    'retainedEarnings': '78704000000',
#    'otherLiabilities': '9648000000',
#    'goodwill': '31350000000',
#    'otherAssets': '10475000000',
#    'cash': '4179000000',
#    'totalCurrentLiabilities': '19728000000',
#    'shortTermDebt': '1767000000',
#    'currentLongTermDebt': '1767000000',
#    'otherShareholderEquity': '-3345000000',
#    'propertyPlantEquipment': '29200000000',
#    'totalCurrentAssets': '16808000000',
#    'longTermInvestments': '3148000000',
#    'netTangibleAssets': '6839000000',
#    'shortTermInvestments': '11000000',
#    'netReceivables': '9678000000',
#    'longTermDebt': '18766000000',
#    'inventory': '2415000000',
#    'accountsPayable': '9022000000',
#    'totalPermanentEquity': '48651000000',
#    'additionalPaidInCapital': '0',
#    'commonStockTotalEquity': '0',
#    'preferredStockTotalEquity': '0',
#    'retainedEarningsTotalEquity': '0',
#    'treasuryStock': '-66619000000',
#    'accumulatedAmortization': 'None',
#    'otherNonCurrrentAssets': 'None',
#    'deferredLongTermAssetCharges': 'None',
#    'totalNonCurrentAssets': 'None',
#    'capitalLeaseObligations': 'None',
#    'totalLongTermDebt': 'None',
#    'otherNonCurrentLiabilities': 'None',
#    'totalNonCurrentLiabilities': 'None',
#    'negativeGoodwill': 'None',
#    'warrants': 'None',
#    'preferredStockRedeemable': 'None',
#    'capitalSurplus': 'None',
#    'liabilitiesAndShareholderEquity': 'None',
#    'cashAndShortTermInvestments': 'None',
#    'accumulatedDepreciation': 'None',
#    'commonStockSharesOutstanding': '1510000000'},
#   {'fiscalDateEnding': '2017-12-30',
#    'reportedCurrency': 'USD',
#    'totalAssets': '97734000000',
#    'intangibleAssets': '38360000000',
#    'earningAssets': 'None',
#    'otherCurrentAssets': '545000000',
#    'totalLiabilities': '49509000000',
#    'totalShareholderEquity': '43289000000',
#    'deferredLongTermLiabilities': '0',
#    'otherCurrentLiabilities': '4292000000',
#    'commonStock': '29000000',
#    'retainedEarnings': '72359000000',
#    'otherLiabilities': '6726000000',
#    'goodwill': '31430000000',
#    'otherAssets': '51876000000',
#    'cash': '4677000000',
#    'totalCurrentLiabilities': '19875000000',
#    'shortTermDebt': '2098000000',
#    'currentLongTermDebt': '2098000000',
#    'otherShareholderEquity': '-3404000000',
#    'propertyPlantEquipment': '28584000000',
#    'totalCurrentAssets': '17274000000',
#    'longTermInvestments': '3206000000',
#    'netTangibleAssets': '4929000000',
#    'shortTermInvestments': '13000000',
#    'netReceivables': '9886000000',
#    'longTermDebt': '20082000000',
#    'inventory': '2153000000',
#    'accountsPayable': '9574000000',
#    'totalPermanentEquity': '47083000000',
#    'additionalPaidInCapital': '0',
#    'commonStockTotalEquity': '0',
#    'preferredStockTotalEquity': '0',
#    'retainedEarningsTotalEquity': '0',
#    'treasuryStock': '-65324000000',
#    'accumulatedAmortization': 'None',
#    'otherNonCurrrentAssets': 'None',
#    'deferredLongTermAssetCharges': 'None',
#    'totalNonCurrentAssets': 'None',
#    'capitalLeaseObligations': 'None',
#    'totalLongTermDebt': 'None',
#    'otherNonCurrentLiabilities': 'None',
#    'totalNonCurrentLiabilities': 'None',
#    'negativeGoodwill': 'None',
#    'warrants': 'None',
#    'preferredStockRedeemable': 'None',
#    'capitalSurplus': 'None',
#    'liabilitiesAndShareholderEquity': 'None',
#    'cashAndShortTermInvestments': 'None',
#    'accumulatedDepreciation': 'None',
#    'commonStockSharesOutstanding': '1521000000'},
#   {'fiscalDateEnding': '2017-09-30',
#    'reportedCurrency': 'USD',
#    'totalAssets': '95789000000',
#    'intangibleAssets': '38421000000',
#    'earningAssets': 'None',
#    'otherCurrentAssets': '562000000',
#    'totalLiabilities': '49637000000',
#    'totalShareholderEquity': '41315000000',
#    'deferredLongTermLiabilities': '0',
#    'otherCurrentLiabilities': '6921000000',
#    'commonStock': '29000000',
#    'retainedEarnings': '69078000000',
#    'otherLiabilities': '6314000000',
#    'goodwill': '31426000000',
#    'otherAssets': '51494000000',
#    'cash': '4017000000',
#    'totalCurrentLiabilities': '19595000000',
#    'shortTermDebt': '3400000000',
#    'currentLongTermDebt': '3400000000',
#    'otherShareholderEquity': '-3528000000',
#    'propertyPlantEquipment': '28406000000',
#    'totalCurrentAssets': '15889000000',
#    'longTermInvestments': '3202000000',
#    'netTangibleAssets': '2894000000',
#    'shortTermInvestments': '26000000',
#    'netReceivables': '8633000000',
#    'longTermDebt': '19248000000',
#    'inventory': '2651000000',
#    'accountsPayable': '6490000000',
#    'totalPermanentEquity': '45004000000',
#    'additionalPaidInCapital': '0',
#    'commonStockTotalEquity': '36248000000',
#    'preferredStockTotalEquity': '0',
#    'retainedEarningsTotalEquity': '72606000000',
#    'treasuryStock': '-64011000000',
#    'accumulatedAmortization': 'None',
#    'otherNonCurrrentAssets': 'None',
#    'deferredLongTermAssetCharges': 'None',
#    'totalNonCurrentAssets': 'None',
#    'capitalLeaseObligations': 'None',
#    'totalLongTermDebt': 'None',
#    'otherNonCurrentLiabilities': 'None',
#    'totalNonCurrentLiabilities': 'None',
#    'negativeGoodwill': 'None',
#    'warrants': 'None',
#    'preferredStockRedeemable': 'None',
#    'capitalSurplus': 'None',
#    'liabilitiesAndShareholderEquity': 'None',
#    'cashAndShortTermInvestments': 'None',
#    'accumulatedDepreciation': 'None',
#    'commonStockSharesOutstanding': '1578000000'},
#   {'fiscalDateEnding': '2017-06-30',
#    'reportedCurrency': 'USD',
#    'totalAssets': '92752000000',
#    'intangibleAssets': '34632000000',
#    'earningAssets': 'None',
#    'otherCurrentAssets': '665000000',
#    'totalLiabilities': '46701000000',
#    'totalShareholderEquity': '42531000000',
#    'deferredLongTermLiabilities': '0',
#    'otherCurrentLiabilities': '4382000000',
#    'commonStock': '29000000',
#    'retainedEarnings': '66999000000',
#    'otherLiabilities': '6581000000',
#    'goodwill': '27835000000',
#    'otherAssets': '47868000000',
#    'cash': '4336000000',
#    'totalCurrentLiabilities': '17094000000',
#    'shortTermDebt': '22187000000',
#    'currentLongTermDebt': '22187000000',
#    'otherShareholderEquity': '-3864000000',
#    'propertyPlantEquipment': '27733000000',
#    'totalCurrentAssets': '17151000000',
#    'longTermInvestments': 'None',
#    'netTangibleAssets': '7899000000',
#    'shortTermInvestments': '0',
#    'netReceivables': '9636000000',
#    'longTermDebt': '18849000000',
#    'inventory': '2514000000',
#    'accountsPayable': '9374000000',
#    'totalPermanentEquity': '46051000000',
#    'additionalPaidInCapital': '0',
#    'commonStockTotalEquity': '0',
#    'preferredStockTotalEquity': '0',
#    'retainedEarningsTotalEquity': '0',
#    'treasuryStock': '-60587000000',
#    'accumulatedAmortization': 'None',
#    'otherNonCurrrentAssets': 'None',
#    'deferredLongTermAssetCharges': 'None',
#    'totalNonCurrentAssets': 'None',
#    'capitalLeaseObligations': 'None',
#    'totalLongTermDebt': 'None',
#    'otherNonCurrentLiabilities': 'None',
#    'totalNonCurrentLiabilities': 'None',
#    'negativeGoodwill': 'None',
#    'warrants': 'None',
#    'preferredStockRedeemable': 'None',
#    'capitalSurplus': 'None',
#    'liabilitiesAndShareholderEquity': 'None',
#    'cashAndShortTermInvestments': 'None',
#    'accumulatedDepreciation': 'None',
#    'commonStockSharesOutstanding': '1572000000'},
#   {'fiscalDateEnding': '2017-03-31',
#    'reportedCurrency': 'USD',
#    'totalAssets': '91807000000',
#    'intangibleAssets': '34676000000',
#    'earningAssets': 'None',
#    'otherCurrentAssets': '740000000',
#    'totalLiabilities': '44540000000',
#    'totalShareholderEquity': '43784000000',
#    'deferredLongTermLiabilities': '0',
#    'otherCurrentLiabilities': '4423000000',
#    'commonStock': '29000000',
#    'retainedEarnings': '65828000000',
#    'otherLiabilities': '6381000000',
#    'goodwill': '27831000000',
#    'otherAssets': '48138000000',
#    'cash': '3800000000',
#    'totalCurrentLiabilities': '17365000000',
#    'shortTermDebt': '4865000000',
#    'currentLongTermDebt': '4865000000',
#    'otherShareholderEquity': '-3880000000',
#    'propertyPlantEquipment': '27399000000',
#    'totalCurrentAssets': '16270000000',
#    'longTermInvestments': 'None',
#    'netTangibleAssets': '9108000000',
#    'shortTermInvestments': '0',
#    'netReceivables': '9293000000',
#    'longTermDebt': '16788000000',
#    'inventory': '2437000000',
#    'accountsPayable': '8077000000',
#    'totalPermanentEquity': '47267000000',
#    'additionalPaidInCapital': '0',
#    'commonStockTotalEquity': '0',
#    'preferredStockTotalEquity': '0',
#    'retainedEarningsTotalEquity': '0',
#    'treasuryStock': '-58144000000',
#    'accumulatedAmortization': 'None',
#    'otherNonCurrrentAssets': 'None',
#    'deferredLongTermAssetCharges': 'None',
#    'totalNonCurrentAssets': 'None',
#    'capitalLeaseObligations': 'None',
#    'totalLongTermDebt': 'None',
#    'otherNonCurrentLiabilities': 'None',
#    'totalNonCurrentLiabilities': 'None',
#    'negativeGoodwill': 'None',
#    'warrants': 'None',
#    'preferredStockRedeemable': 'None',
#    'capitalSurplus': 'None',
#    'liabilitiesAndShareholderEquity': 'None',
#    'cashAndShortTermInvestments': 'None',
#    'accumulatedDepreciation': 'None',
#    'commonStockSharesOutstanding': '1591000000'},
#   {'fiscalDateEnding': '2016-12-31',
#    'reportedCurrency': 'USD',
#    'totalAssets': '91576000000',
#    'intangibleAssets': '34685000000',
#    'earningAssets': 'None',
#    'otherCurrentAssets': '931000000',
#    'totalLiabilities': '44399000000',
#    'totalShareholderEquity': '43210000000',
#    'deferredLongTermLiabilities': '0',
#    'otherCurrentLiabilities': '3640000000',
#    'commonStock': '29000000',
#    'retainedEarnings': '63472000000',
#    'otherLiabilities': '6402000000',
#    'goodwill': '27793000000',
#    'otherAssets': '47857000000',
#    'cash': '3736000000',
#    'totalCurrentLiabilities': '19317000000',
#    'shortTermDebt': '5698000000',
#    'currentLongTermDebt': '5698000000',
#    'otherShareholderEquity': '-3855000000',
#    'propertyPlantEquipment': '27054000000',
#    'totalCurrentAssets': '16665000000',
#    'longTermInvestments': 'None',
#    'netTangibleAssets': '8525000000',
#    'shortTermInvestments': '0',
#    'netReceivables': '9878000000',
#    'longTermDebt': '14792000000',
#    'inventory': '2120000000',
#    'accountsPayable': '9979000000',
#    'totalPermanentEquity': '47177000000',
#    'additionalPaidInCapital': '0',
#    'commonStockTotalEquity': '0',
#    'preferredStockTotalEquity': '0',
#    'retainedEarningsTotalEquity': '0',
#    'treasuryStock': '-56168000000',
#    'accumulatedAmortization': 'None',
#    'otherNonCurrrentAssets': 'None',
#    'deferredLongTermAssetCharges': 'None',
#    'totalNonCurrentAssets': 'None',
#    'capitalLeaseObligations': 'None',
#    'totalLongTermDebt': 'None',
#    'otherNonCurrentLiabilities': 'None',
#    'totalNonCurrentLiabilities': 'None',
#    'negativeGoodwill': 'None',
#    'warrants': 'None',
#    'preferredStockRedeemable': 'None',
#    'capitalSurplus': 'None',
#    'liabilitiesAndShareholderEquity': 'None',
#    'cashAndShortTermInvestments': 'None',
#    'accumulatedDepreciation': 'None',
#    'commonStockSharesOutstanding': '1603000000'},
#   {'fiscalDateEnding': '2016-09-30',
#    'reportedCurrency': 'USD',
#    'totalAssets': '92033000000',
#    'intangibleAssets': '34759000000',
#    'earningAssets': 'None',
#    'otherCurrentAssets': '693000000',
#    'totalLiabilities': '44710000000',
#    'totalShareholderEquity': '43265000000',
#    'deferredLongTermLiabilities': '0',
#    'otherCurrentLiabilities': '6275000000',
#    'commonStock': '29000000',
#    'retainedEarnings': '62109000000',
#    'otherLiabilities': '7532000000',
#    'goodwill': '27810000000',
#    'otherAssets': '47718000000',
#    'cash': '4610000000',
#    'totalCurrentLiabilities': '16842000000',
#    'shortTermDebt': '2166000000',
#    'currentLongTermDebt': '2166000000',
#    'otherShareholderEquity': '-3979000000',
#    'propertyPlantEquipment': '27349000000',
#    'totalCurrentAssets': '16966000000',
#    'longTermInvestments': '4258000000',
#    'netTangibleAssets': '8506000000',
#    'shortTermInvestments': '0',
#    'netReceivables': '9065000000',
#    'longTermDebt': '16657000000',
#    'inventory': '2598000000',
#    'accountsPayable': '6860000000',
#    'totalPermanentEquity': '47323000000',
#    'additionalPaidInCapital': '0',
#    'commonStockTotalEquity': '35859000000',
#    'preferredStockTotalEquity': '0',
#    'retainedEarningsTotalEquity': '66088000000',
#    'treasuryStock': '-54703000000',
#    'accumulatedAmortization': 'None',
#    'otherNonCurrrentAssets': 'None',
#    'deferredLongTermAssetCharges': 'None',
#    'totalNonCurrentAssets': 'None',
#    'capitalLeaseObligations': 'None',
#    'totalLongTermDebt': 'None',
#    'otherNonCurrentLiabilities': 'None',
#    'totalNonCurrentLiabilities': 'None',
#    'negativeGoodwill': 'None',
#    'warrants': 'None',
#    'preferredStockRedeemable': 'None',
#    'capitalSurplus': 'None',
#    'liabilitiesAndShareholderEquity': 'None',
#    'cashAndShortTermInvestments': 'None',
#    'accumulatedDepreciation': 'None',
#    'commonStockSharesOutstanding': '1639000000'},
#   {'fiscalDateEnding': '2016-07-02',
#    'reportedCurrency': 'USD',
#    'totalAssets': '90914000000',
#    'intangibleAssets': '34797000000',
#    'earningAssets': 'None',
#    'otherCurrentAssets': '847000000',
#    'totalLiabilities': '42768000000',
#    'totalShareholderEquity': '44193000000',
#    'deferredLongTermLiabilities': '0',
#    'otherCurrentLiabilities': '4041000000',
#    'commonStock': '29000000',
#    'retainedEarnings': '61622000000',
#    'otherLiabilities': '5491000000',
#    'goodwill': '27802000000',
#    'otherAssets': '46432000000',
#    'cash': '5227000000',
#    'totalCurrentLiabilities': '18072000000',
#    'shortTermDebt': '5312000000',
#    'currentLongTermDebt': '5312000000',
#    'otherShareholderEquity': '-2699000000',
#    'propertyPlantEquipment': '26865000000',
#    'totalCurrentAssets': '17617000000',
#    'longTermInvestments': 'None',
#    'netTangibleAssets': '9396000000',
#    'shortTermInvestments': '0',
#    'netReceivables': '8958000000',
#    'longTermDebt': '15129000000',
#    'inventory': '2585000000',
#    'accountsPayable': '8719000000',
#    'totalPermanentEquity': '48146000000',
#    'additionalPaidInCapital': '0',
#    'commonStockTotalEquity': '0',
#    'preferredStockTotalEquity': '0',
#    'retainedEarningsTotalEquity': '0',
#    'treasuryStock': '-53112000000',
#    'accumulatedAmortization': 'None',
#    'otherNonCurrrentAssets': 'None',
#    'deferredLongTermAssetCharges': 'None',
#    'totalNonCurrentAssets': 'None',
#    'capitalLeaseObligations': 'None',
#    'totalLongTermDebt': 'None',
#    'otherNonCurrentLiabilities': 'None',
#    'totalNonCurrentLiabilities': 'None',
#    'negativeGoodwill': 'None',
#    'warrants': 'None',
#    'preferredStockRedeemable': 'None',
#    'capitalSurplus': 'None',
#    'liabilitiesAndShareholderEquity': 'None',
#    'cashAndShortTermInvestments': 'None',
#    'accumulatedDepreciation': 'None',
#    'commonStockSharesOutstanding': 'None'},
#   {'fiscalDateEnding': '2016-04-02',
#    'reportedCurrency': 'USD',
#    'totalAssets': '90264000000',
#    'intangibleAssets': '34869000000',
#    'earningAssets': 'None',
#    'otherCurrentAssets': '781000000',
#    'totalLiabilities': '42254000000',
#    'totalShareholderEquity': '44124000000',
#    'deferredLongTermLiabilities': '0',
#    'otherCurrentLiabilities': '4066000000',
#    'commonStock': '29000000',
#    'retainedEarnings': '60271000000',
#    'otherLiabilities': '5770000000',
#    'goodwill': '27817000000',
#    'otherAssets': '46844000000',
#    'cash': '5015000000',
#    'totalCurrentLiabilities': '17073000000',
#    'shortTermDebt': '5755000000',
#    'currentLongTermDebt': '5755000000',
#    'otherShareholderEquity': '-2599000000',
#    'propertyPlantEquipment': '26421000000',
#    'totalCurrentAssets': '0',
#    'longTermInvestments': 'None',
#    'netTangibleAssets': '9255000000',
#    'shortTermInvestments': '0',
#    'netReceivables': '8874000000',
#    'longTermDebt': '15367000000',
#    'inventory': '2329000000',
#    'accountsPayable': '7252000000',
#    'totalPermanentEquity': '0',
#    'additionalPaidInCapital': '0',
#    'commonStockTotalEquity': '0',
#    'preferredStockTotalEquity': '0',
#    'retainedEarningsTotalEquity': '0',
#    'treasuryStock': '-51595000000',
#    'accumulatedAmortization': 'None',
#    'otherNonCurrrentAssets': 'None',
#    'deferredLongTermAssetCharges': 'None',
#    'totalNonCurrentAssets': 'None',
#    'capitalLeaseObligations': 'None',
#    'totalLongTermDebt': 'None',
#    'otherNonCurrentLiabilities': 'None',
#    'totalNonCurrentLiabilities': 'None',
#    'negativeGoodwill': 'None',
#    'warrants': 'None',
#    'preferredStockRedeemable': 'None',
#    'capitalSurplus': 'None',
#    'liabilitiesAndShareholderEquity': 'None',
#    'cashAndShortTermInvestments': 'None',
#    'accumulatedDepreciation': 'None',
#    'commonStockSharesOutstanding': 'None'},
#   {'fiscalDateEnding': '2016-01-02',
#    'reportedCurrency': 'USD',
#    'totalAssets': '90121000000',
#    'intangibleAssets': '34922000000',
#    'earningAssets': 'None',
#    'otherCurrentAssets': '924000000',
#    'totalLiabilities': '41923000000',
#    'totalShareholderEquity': '43958000000',
#    'deferredLongTermLiabilities': '0',
#    'otherCurrentLiabilities': '3526000000',
#    'commonStock': '29000000',
#    'retainedEarnings': '58265000000',
#    'otherLiabilities': '6288000000',
#    'goodwill': '27818000000',
#    'otherAssets': '46866000000',
#    'cash': '4301000000',
#    'totalCurrentLiabilities': '18796000000',
#    'shortTermDebt': 'None',
#    'currentLongTermDebt': 'None',
#    'otherShareholderEquity': 'None',
#    'propertyPlantEquipment': '25487000000',
#    'totalCurrentAssets': '0',
#    'longTermInvestments': 'None',
#    'netTangibleAssets': 'None',
#    'shortTermInvestments': '0',
#    'netReceivables': 'None',
#    'longTermDebt': '12965000000',
#    'inventory': '2245000000',
#    'accountsPayable': '9320000000',
#    'totalPermanentEquity': '0',
#    'additionalPaidInCapital': '0',
#    'commonStockTotalEquity': '0',
#    'preferredStockTotalEquity': '0',
#    'retainedEarningsTotalEquity': '0',
#    'treasuryStock': '-49556000000',
#    'accumulatedAmortization': 'None',
#    'otherNonCurrrentAssets': 'None',
#    'deferredLongTermAssetCharges': 'None',
#    'totalNonCurrentAssets': 'None',
#    'capitalLeaseObligations': 'None',
#    'totalLongTermDebt': 'None',
#    'otherNonCurrentLiabilities': 'None',
#    'totalNonCurrentLiabilities': 'None',
#    'negativeGoodwill': 'None',
#    'warrants': 'None',
#    'preferredStockRedeemable': 'None',
#    'capitalSurplus': 'None',
#    'liabilitiesAndShareholderEquity': 'None',
#    'cashAndShortTermInvestments': 'None',
#    'accumulatedDepreciation': 'None',
#    'commonStockSharesOutstanding': 'None'},
#   {'fiscalDateEnding': '2015-10-03',
#    'reportedCurrency': 'USD',
#    'totalAssets': '88182000000',
#    'intangibleAssets': '34998000000',
#    'earningAssets': 'None',
#    'otherCurrentAssets': '1729000000',
#    'totalLiabilities': '39527000000',
#    'totalShareholderEquity': '44525000000',
#    'deferredLongTermLiabilities': '0',
#    'otherCurrentLiabilities': '6240000000',
#    'commonStock': '29000000',
#    'retainedEarnings': '56607000000',
#    'otherLiabilities': '6174000000',
#    'goodwill': '27826000000',
#    'otherAssets': '46245000000',
#    'cash': '4269000000',
#    'totalCurrentLiabilities': '16334000000',
#    'shortTermDebt': '2133000000',
#    'currentLongTermDebt': '2133000000',
#    'otherShareholderEquity': '-2421000000',
#    'propertyPlantEquipment': '25179000000',
#    'totalCurrentAssets': '16758000000',
#    'longTermInvestments': '2600000000',
#    'netTangibleAssets': '9527000000',
#    'shortTermInvestments': '0',
#    'netReceivables': '8019000000',
#    'longTermDebt': '12968000000',
#    'inventory': '2741000000',
#    'accountsPayable': '5504000000',
#    'totalPermanentEquity': '0',
#    'additionalPaidInCapital': '0',
#    'commonStockTotalEquity': '0',
#    'preferredStockTotalEquity': '0',
#    'retainedEarningsTotalEquity': '0',
#    'treasuryStock': '-47204000000',
#    'accumulatedAmortization': 'None',
#    'otherNonCurrrentAssets': 'None',
#    'deferredLongTermAssetCharges': 'None',
#    'totalNonCurrentAssets': 'None',
#    'capitalLeaseObligations': 'None',
#    'totalLongTermDebt': 'None',
#    'otherNonCurrentLiabilities': 'None',
#    'totalNonCurrentLiabilities': 'None',
#    'negativeGoodwill': 'None',
#    'warrants': 'None',
#    'preferredStockRedeemable': 'None',
#    'capitalSurplus': 'None',
#    'liabilitiesAndShareholderEquity': 'None',
#    'cashAndShortTermInvestments': 'None',
#    'accumulatedDepreciation': 'None',
#    'commonStockSharesOutstanding': 'None'}]}

# %%
dis_annual_cash_flow_statement_response.json()
# Out:
# {'symbol': 'DIS',
#  'annualReports': [{'fiscalDateEnding': '2019-09-30',
#    'reportedCurrency': 'USD',
#    'investments': '-4118000000',
#    'changeInLiabilities': '191000000',
#    'cashflowFromInvestment': '-4118000000',
#    'otherCashflowFromInvestment': '10659000000',
#    'netBorrowings': '3677000000',
#    'cashflowFromFinancing': '-464000000',
#    'otherCashflowFromFinancing': '-2190000000',
#    'changeInOperatingActivities': '932000000',
#    'netIncome': '11054000000',
#    'changeInCash': '1300000000',
#    'operatingCashflow': '6606000000',
#    'otherOperatingCashflow': 'None',
#    'depreciation': '4160000000',
#    'dividendPayout': '-2895000000',
#    'stockSaleAndPurchase': '0',
#    'changeInInventory': '-223000000',
#    'changeInAccountReceivables': '55000000',
#    'changeInNetIncome': '-2964000000',
#    'capitalExpenditures': '4876000000',
#    'changeInReceivables': 'None',
#    'changeInExchangeRate': 'None',
#    'changeInCashAndCashEquivalents': 'None'},
#   {'fiscalDateEnding': '2018-09-30',
#    'reportedCurrency': 'USD',
#    'investments': '-5336000000',
#    'changeInLiabilities': '235000000',
#    'cashflowFromInvestment': '-5336000000',
#    'otherCashflowFromInvestment': '710000000',
#    'netBorrowings': '-2583000000',
#    'cashflowFromFinancing': '-8843000000',
#    'otherCashflowFromFinancing': '-378000000',
#    'changeInOperatingActivities': '-927000000',
#    'netIncome': '12598000000',
#    'changeInCash': '91000000',
#    'operatingCashflow': '14295000000',
#    'otherOperatingCashflow': 'None',
#    'depreciation': '3011000000',
#    'dividendPayout': '-2515000000',
#    'stockSaleAndPurchase': '-3577000000',
#    'changeInInventory': '-17000000',
#    'changeInAccountReceivables': '-720000000',
#    'changeInNetIncome': '-477000000',
#    'capitalExpenditures': '4465000000',
#    'changeInReceivables': 'None',
#    'changeInExchangeRate': 'None',
#    'changeInCashAndCashEquivalents': 'None'},
#   {'fiscalDateEnding': '2017-09-30',
#    'reportedCurrency': 'USD',
#    'investments': '-4111000000',
#    'changeInLiabilities': '-368000000',
#    'cashflowFromInvestment': '-4111000000',
#    'otherCashflowFromInvestment': '-71000000',
#    'netBorrowings': '3703000000',
#    'cashflowFromFinancing': '-8959000000',
#    'otherCashflowFromFinancing': '-1125000000',
#    'changeInOperatingActivities': '-52000000',
#    'netIncome': '8980000000',
#    'changeInCash': '-696000000',
#    'operatingCashflow': '12343000000',
#    'otherOperatingCashflow': 'None',
#    'depreciation': '2782000000',
#    'dividendPayout': '-2445000000',
#    'stockSaleAndPurchase': '-9368000000',
#    'changeInInventory': '-5000000',
#    'changeInAccountReceivables': '107000000',
#    'changeInNetIncome': '691000000',
#    'capitalExpenditures': '3623000000',
#    'changeInReceivables': 'None',
#    'changeInExchangeRate': 'None',
#    'changeInCashAndCashEquivalents': 'None'},
#   {'fiscalDateEnding': '2016-10-01',
#    'reportedCurrency': 'USD',
#    'investments': '-5758000000',
#    'changeInLiabilities': '40000000',
#    'cashflowFromInvestment': '-5758000000',
#    'otherCashflowFromInvestment': '-135000000',
#    'netBorrowings': '2940000000',
#    'cashflowFromFinancing': '-6991000000',
#    'otherCashflowFromFinancing': '-607000000',
#    'changeInOperatingActivities': '-443000000',
#    'netIncome': '9391000000',
#    'changeInCash': '341000000',
#    'operatingCashflow': '13136000000',
#    'otherOperatingCashflow': 'None',
#    'depreciation': '2527000000',
#    'dividendPayout': '-2313000000',
#    'stockSaleAndPurchase': '-7499000000',
#    'changeInInventory': '186000000',
#    'changeInAccountReceivables': '-393000000',
#    'changeInNetIncome': '2426000000',
#    'capitalExpenditures': '4773000000',
#    'changeInReceivables': 'None',
#    'changeInExchangeRate': 'None',
#    'changeInCashAndCashEquivalents': 'None'},
#   {'fiscalDateEnding': '2016-09-30',
#    'reportedCurrency': 'USD',
#    'investments': '-5758000000',
#    'changeInLiabilities': '40000000',
#    'cashflowFromInvestment': '-5758000000',
#    'otherCashflowFromInvestment': '-135000000',
#    'netBorrowings': '2940000000',
#    'cashflowFromFinancing': '-6991000000',
#    'otherCashflowFromFinancing': '-607000000',
#    'changeInOperatingActivities': '-443000000',
#    'netIncome': '9391000000',
#    'changeInCash': '341000000',
#    'operatingCashflow': '13136000000',
#    'otherOperatingCashflow': 'None',
#    'depreciation': '2527000000',
#    'dividendPayout': '-2313000000',
#    'stockSaleAndPurchase': '-7499000000',
#    'changeInInventory': '186000000',
#    'changeInAccountReceivables': 'None',
#    'changeInNetIncome': '2426000000',
#    'capitalExpenditures': '4773000000',
#    'changeInReceivables': 'None',
#    'changeInExchangeRate': 'None',
#    'changeInCashAndCashEquivalents': 'None'}],
#  'quarterlyReports': [{'fiscalDateEnding': '2020-06-30',
#    'reportedCurrency': 'USD',
#    'investments': '-714000000',
#    'changeInLiabilities': '-1098000000',
#    'cashflowFromInvestment': '-714000000',
#    'otherCashflowFromInvestment': '-6000000',
#    'netBorrowings': '8945000000',
#    'cashflowFromFinancing': '8303000000',
#    'otherCashflowFromFinancing': '-673000000',
#    'changeInOperatingActivities': '182000000',
#    'netIncome': '-4721000000',
#    'changeInCash': '8776000000',
#    'operatingCashflow': '1162000000',
#    'otherOperatingCashflow': 'None',
#    'depreciation': '1379000000',
#    'dividendPayout': '0',
#    'stockSaleAndPurchase': 'None',
#    'changeInInventory': '16000000',
#    'changeInAccountReceivables': 'None',
#    'changeInNetIncome': '3923000000',
#    'capitalExpenditures': '708000000',
#    'changeInReceivables': 'None',
#    'changeInExchangeRate': 'None',
#    'changeInCashAndCashEquivalents': 'None'},
#   {'fiscalDateEnding': '2020-03-31',
#    'reportedCurrency': 'USD',
#    'investments': '-1058000000',
#    'changeInLiabilities': '-47000000',
#    'cashflowFromInvestment': '-1058000000',
#    'otherCashflowFromInvestment': '189000000',
#    'netBorrowings': '6984000000',
#    'cashflowFromFinancing': '5499000000',
#    'otherCashflowFromFinancing': '21000000',
#    'changeInOperatingActivities': '-141000000',
#    'netIncome': '460000000',
#    'changeInCash': '7504000000',
#    'operatingCashflow': '3157000000',
#    'otherOperatingCashflow': 'None',
#    'depreciation': '1333000000',
#    'dividendPayout': '-1587000000',
#    'stockSaleAndPurchase': '207000000',
#    'changeInInventory': '-11000000',
#    'changeInAccountReceivables': 'None',
#    'changeInNetIncome': '-810000000',
#    'capitalExpenditures': '1247000000',
#    'changeInReceivables': 'None',
#    'changeInExchangeRate': 'None',
#    'changeInCashAndCashEquivalents': 'None'},
#   {'fiscalDateEnding': '2019-12-31',
#    'reportedCurrency': 'USD',
#    'investments': '-1350000000',
#    'changeInLiabilities': '-841000000',
#    'cashflowFromInvestment': '-1350000000',
#    'otherCashflowFromInvestment': '-12000000',
#    'netBorrowings': '1177000000',
#    'cashflowFromFinancing': '1117000000',
#    'otherCashflowFromFinancing': '-186000000',
#    'changeInOperatingActivities': '-33000000',
#    'netIncome': '2107000000',
#    'changeInCash': '1419000000',
#    'operatingCashflow': '1630000000',
#    'otherOperatingCashflow': 'None',
#    'depreciation': '1298000000',
#    'dividendPayout': 'None',
#    'stockSaleAndPurchase': '126000000',
#    'changeInInventory': '81000000',
#    'changeInAccountReceivables': '-1424000000',
#    'changeInNetIncome': '679000000',
#    'capitalExpenditures': '1338000000',
#    'changeInReceivables': 'None',
#    'changeInExchangeRate': 'None',
#    'changeInCashAndCashEquivalents': 'None'},
#   {'fiscalDateEnding': '2019-09-30',
#    'reportedCurrency': 'USD',
#    'investments': '9667000000',
#    'changeInLiabilities': '-28000000',
#    'cashflowFromInvestment': '9667000000',
#    'otherCashflowFromInvestment': '10976000000',
#    'netBorrowings': '-11605000000',
#    'cashflowFromFinancing': '-12997000000',
#    'otherCashflowFromFinancing': '-294000000',
#    'changeInOperatingActivities': '482000000',
#    'netIncome': '1054000000',
#    'changeInCash': '-1902000000',
#    'operatingCashflow': '1718000000',
#    'otherOperatingCashflow': 'None',
#    'depreciation': '1296000000',
#    'dividendPayout': '-1585000000',
#    'stockSaleAndPurchase': '0',
#    'changeInInventory': '-127000000',
#    'changeInAccountReceivables': '1483000000',
#    'changeInNetIncome': '-1789000000',
#    'capitalExpenditures': '1309000000',
#    'changeInReceivables': 'None',
#    'changeInExchangeRate': 'None',
#    'changeInCashAndCashEquivalents': 'None'},
#   {'fiscalDateEnding': '2019-06-30',
#    'reportedCurrency': 'USD',
#    'investments': '-1102000000',
#    'changeInLiabilities': '502000000',
#    'cashflowFromInvestment': '-1102000000',
#    'otherCashflowFromInvestment': '75000000',
#    'netBorrowings': '1159000000',
#    'cashflowFromFinancing': '-163000000',
#    'otherCashflowFromFinancing': '-1696000000',
#    'changeInOperatingActivities': '404000000',
#    'netIncome': '1760000000',
#    'changeInCash': '-2865000000',
#    'operatingCashflow': '-1748000000',
#    'otherOperatingCashflow': 'None',
#    'depreciation': '1304000000',
#    'dividendPayout': '0',
#    'stockSaleAndPurchase': '0',
#    'changeInInventory': '-77000000',
#    'changeInAccountReceivables': '-1042000000',
#    'changeInNetIncome': '1530000000',
#    'capitalExpenditures': '1177000000',
#    'changeInReceivables': 'None',
#    'changeInExchangeRate': 'None',
#    'changeInCashAndCashEquivalents': 'None'},
#   {'fiscalDateEnding': '2019-03-31',
#    'reportedCurrency': 'USD',
#    'investments': '-11347000000',
#    'changeInLiabilities': '0',
#    'cashflowFromInvestment': '-1102000000',
#    'otherCashflowFromInvestment': '75000000',
#    'netBorrowings': '1159000000',
#    'cashflowFromFinancing': '13107000000',
#    'otherCashflowFromFinancing': '-1696000000',
#    'changeInOperatingActivities': '404000000',
#    'netIncome': '5452000000',
#    'changeInCash': '5759000000',
#    'operatingCashflow': '3915000000',
#    'otherOperatingCashflow': 'None',
#    'depreciation': '828000000',
#    'dividendPayout': '-1585000000',
#    'stockSaleAndPurchase': '83000000',
#    'changeInInventory': '-51000000',
#    'changeInAccountReceivables': '-1042000000',
#    'changeInNetIncome': '1530000000',
#    'capitalExpenditures': '1195000000',
#    'changeInReceivables': 'None',
#    'changeInExchangeRate': 'None',
#    'changeInCashAndCashEquivalents': 'None'},
#   {'fiscalDateEnding': '2018-12-29',
#    'reportedCurrency': 'USD',
#    'investments': 'None',
#    'changeInLiabilities': '-1289000000',
#    'cashflowFromInvestment': '-1336000000',
#    'otherCashflowFromInvestment': '-141000000',
#    'netBorrowings': '-302000000',
#    'cashflowFromFinancing': '-411000000',
#    'otherCashflowFromFinancing': '-146000000',
#    'changeInOperatingActivities': '25000000',
#    'netIncome': '2788000000',
#    'changeInCash': '308000000',
#    'operatingCashflow': '2099000000',
#    'otherOperatingCashflow': 'None',
#    'depreciation': '732000000',
#    'dividendPayout': '-1585000000',
#    'stockSaleAndPurchase': '37000000',
#    'changeInInventory': '32000000',
#    'changeInAccountReceivables': '-1078000000',
#    'changeInNetIncome': '759000000',
#    'capitalExpenditures': '1195000000',
#    'changeInReceivables': 'None',
#    'changeInExchangeRate': 'None',
#    'changeInCashAndCashEquivalents': 'None'},
#   {'fiscalDateEnding': '2018-09-29',
#    'reportedCurrency': 'USD',
#    'investments': 'None',
#    'changeInLiabilities': '551000000',
#    'cashflowFromInvestment': '-193000000',
#    'otherCashflowFromInvestment': '1008000000',
#    'netBorrowings': '-2736000000',
#    'cashflowFromFinancing': '-3862000000',
#    'otherCashflowFromFinancing': '42000000',
#    'changeInOperatingActivities': '-455000000',
#    'netIncome': '2322000000',
#    'changeInCash': '-176000000',
#    'operatingCashflow': '3853000000',
#    'otherOperatingCashflow': 'None',
#    'depreciation': '794000000',
#    'dividendPayout': '-1249000000',
#    'stockSaleAndPurchase': '0',
#    'changeInInventory': '-70000000',
#    'changeInAccountReceivables': '458000000',
#    'changeInNetIncome': '95000000',
#    'capitalExpenditures': '1201000000',
#    'changeInReceivables': 'None',
#    'changeInExchangeRate': 'None',
#    'changeInCashAndCashEquivalents': 'None'},
#   {'fiscalDateEnding': '2018-06-30',
#    'reportedCurrency': 'USD',
#    'investments': 'None',
#    'changeInLiabilities': '-224000000',
#    'cashflowFromInvestment': '-1338000000',
#    'otherCashflowFromInvestment': '-118000000',
#    'netBorrowings': '-917000000',
#    'cashflowFromFinancing': '-2099000000',
#    'otherCashflowFromFinancing': '-251000000',
#    'changeInOperatingActivities': '-224000000',
#    'netIncome': '2916000000',
#    'changeInCash': '136000000',
#    'operatingCashflow': '3679000000',
#    'otherOperatingCashflow': 'None',
#    'depreciation': '744000000',
#    'dividendPayout': '-1249000000',
#    'stockSaleAndPurchase': '0',
#    'changeInInventory': '-11000000',
#    'changeInAccountReceivables': '-174000000',
#    'changeInNetIncome': '624000000',
#    'capitalExpenditures': '1220000000',
#    'changeInReceivables': 'None',
#    'changeInExchangeRate': 'None',
#    'changeInCashAndCashEquivalents': 'None'},
#   {'fiscalDateEnding': '2018-03-31',
#    'reportedCurrency': 'USD',
#    'investments': 'None',
#    'changeInLiabilities': '1068000000',
#    'cashflowFromInvestment': '-2762000000',
#    'otherCashflowFromInvestment': '-118000000',
#    'netBorrowings': '235000000',
#    'cashflowFromFinancing': '-2298000000',
#    'otherCashflowFromFinancing': '-13000000',
#    'changeInOperatingActivities': '-219000000',
#    'netIncome': '2937000000',
#    'changeInCash': '-500000000',
#    'operatingCashflow': '4526000000',
#    'otherOperatingCashflow': 'None',
#    'depreciation': '731000000',
#    'dividendPayout': '-1266000000',
#    'stockSaleAndPurchase': '0',
#    'changeInInventory': '-1000000',
#    'changeInAccountReceivables': '374000000',
#    'changeInNetIncome': '86000000',
#    'capitalExpenditures': '1063000000',
#    'changeInReceivables': 'None',
#    'changeInExchangeRate': 'None',
#    'changeInCashAndCashEquivalents': 'None'},
#   {'fiscalDateEnding': '2017-12-30',
#    'reportedCurrency': 'USD',
#    'investments': 'None',
#    'changeInLiabilities': '-1160000000',
#    'cashflowFromInvestment': '-1043000000',
#    'otherCashflowFromInvestment': '-62000000',
#    'netBorrowings': '835000000',
#    'cashflowFromFinancing': '-584000000',
#    'otherCashflowFromFinancing': '-156000000',
#    'changeInOperatingActivities': '-29000000',
#    'netIncome': '4423000000',
#    'changeInCash': '631000000',
#    'operatingCashflow': '2237000000',
#    'otherOperatingCashflow': 'None',
#    'depreciation': '742000000',
#    'dividendPayout': '-1266000000',
#    'stockSaleAndPurchase': '0',
#    'changeInInventory': '99000000',
#    'changeInAccountReceivables': '-1378000000',
#    'changeInNetIncome': '-1282000000',
#    'capitalExpenditures': '981000000',
#    'changeInReceivables': 'None',
#    'changeInExchangeRate': 'None',
#    'changeInCashAndCashEquivalents': 'None'},
#   {'fiscalDateEnding': '2017-09-30',
#    'reportedCurrency': 'USD',
#    'investments': 'None',
#    'changeInLiabilities': '-368000000',
#    'cashflowFromInvestment': '-4111000000',
#    'otherCashflowFromInvestment': '-71000000',
#    'netBorrowings': '3703000000',
#    'cashflowFromFinancing': '-8959000000',
#    'otherCashflowFromFinancing': '-1125000000',
#    'changeInOperatingActivities': '-52000000',
#    'netIncome': '1747000000',
#    'changeInCash': '-696000000',
#    'operatingCashflow': '12343000000',
#    'otherOperatingCashflow': 'None',
#    'depreciation': '2782000000',
#    'dividendPayout': '-2445000000',
#    'stockSaleAndPurchase': '0',
#    'changeInInventory': '-5000000',
#    'changeInAccountReceivables': '107000000',
#    'changeInNetIncome': '691000000',
#    'capitalExpenditures': '3623000000',
#    'changeInReceivables': 'None',
#    'changeInExchangeRate': 'None',
#    'changeInCashAndCashEquivalents': 'None'},
#   {'fiscalDateEnding': '2017-06-30',
#    'reportedCurrency': 'USD',
#    'investments': '557000000',
#    'changeInLiabilities': '1153000000',
#    'cashflowFromInvestment': '-3290000000',
#    'otherCashflowFromInvestment': '0',
#    'netBorrowings': '471000000',
#    'cashflowFromFinancing': '-5792000000',
#    'otherCashflowFromFinancing': '-840000000',
#    'changeInOperatingActivities': '27000000',
#    'netIncome': '2366000000',
#    'changeInCash': '536000000',
#    'operatingCashflow': '8831000000',
#    'otherOperatingCashflow': 'None',
#    'depreciation': '0',
#    'dividendPayout': '-1237000000',
#    'stockSaleAndPurchase': '0',
#    'changeInInventory': '-93000000',
#    'changeInAccountReceivables': '0',
#    'changeInNetIncome': '223000000',
#    'capitalExpenditures': '2728000000',
#    'changeInReceivables': 'None',
#    'changeInExchangeRate': 'None',
#    'changeInCashAndCashEquivalents': 'None'},
#   {'fiscalDateEnding': '2017-03-31',
#    'reportedCurrency': 'USD',
#    'investments': '-557000000',
#    'changeInLiabilities': '-227000000',
#    'cashflowFromInvestment': '-2390000000',
#    'otherCashflowFromInvestment': '90000000',
#    'netBorrowings': '1154000000',
#    'cashflowFromFinancing': '-3049000000',
#    'otherCashflowFromFinancing': '-65000000',
#    'changeInOperatingActivities': '-208000000',
#    'netIncome': '2388000000',
#    'changeInCash': '-121000000',
#    'operatingCashflow': '4698000000',
#    'otherOperatingCashflow': 'None',
#    'depreciation': '0',
#    'dividendPayout': '-1237000000',
#    'stockSaleAndPurchase': '0',
#    'changeInInventory': '-90000000',
#    'changeInAccountReceivables': '0',
#    'changeInNetIncome': '-391000000',
#    'capitalExpenditures': '1923000000',
#    'changeInReceivables': 'None',
#    'changeInExchangeRate': 'None',
#    'changeInCashAndCashEquivalents': 'None'},
#   {'fiscalDateEnding': '2016-12-31',
#    'reportedCurrency': 'USD',
#    'investments': 'None',
#    'changeInLiabilities': '-1716000000',
#    'cashflowFromInvestment': '-1035000000',
#    'otherCashflowFromInvestment': '5000000',
#    'netBorrowings': '580000000',
#    'cashflowFromFinancing': '-987000000',
#    'otherCashflowFromFinancing': '-167000000',
#    'changeInOperatingActivities': '126000000',
#    'netIncome': '2479000000',
#    'changeInCash': '-874000000',
#    'operatingCashflow': '1260000000',
#    'otherOperatingCashflow': 'None',
#    'depreciation': '0',
#    'dividendPayout': '0',
#    'stockSaleAndPurchase': '0',
#    'changeInInventory': '542000000',
#    'changeInAccountReceivables': '0',
#    'changeInNetIncome': '733000000',
#    'capitalExpenditures': '1040000000',
#    'changeInReceivables': 'None',
#    'changeInExchangeRate': 'None',
#    'changeInCashAndCashEquivalents': 'None'},
#   {'fiscalDateEnding': '2016-09-30',
#    'reportedCurrency': 'USD',
#    'investments': '-850000000',
#    'changeInLiabilities': '40000000',
#    'cashflowFromInvestment': '-5758000000',
#    'otherCashflowFromInvestment': '-135000000',
#    'netBorrowings': '2940000000',
#    'cashflowFromFinancing': '-7220000000',
#    'otherCashflowFromFinancing': '-607000000',
#    'changeInOperatingActivities': '-443000000',
#    'netIncome': '1771000000',
#    'changeInCash': '35000000',
#    'operatingCashflow': '13213000000',
#    'otherOperatingCashflow': 'None',
#    'depreciation': '2527000000',
#    'dividendPayout': '-2313000000',
#    'stockSaleAndPurchase': '0',
#    'changeInInventory': '85000000',
#    'changeInAccountReceivables': '-393000000',
#    'changeInNetIncome': '2426000000',
#    'capitalExpenditures': '4773000000',
#    'changeInReceivables': 'None',
#    'changeInExchangeRate': 'None',
#    'changeInCashAndCashEquivalents': 'None'},
#   {'fiscalDateEnding': '2016-07-02',
#    'reportedCurrency': 'USD',
#    'investments': '44000000',
#    'changeInLiabilities': '452000000',
#    'cashflowFromInvestment': '-4226000000',
#    'otherCashflowFromInvestment': '0',
#    'netBorrowings': '-691000000',
#    'cashflowFromFinancing': '-4091000000',
#    'otherCashflowFromFinancing': '265000000',
#    'changeInOperatingActivities': '-150000000',
#    'netIncome': '2597000000',
#    'changeInCash': '212000000',
#    'operatingCashflow': '9386000000',
#    'otherOperatingCashflow': 'None',
#    'depreciation': '0',
#    'dividendPayout': '-1168000000',
#    'stockSaleAndPurchase': '0',
#    'changeInInventory': '-214000000',
#    'changeInAccountReceivables': '0',
#    'changeInNetIncome': '44000000',
#    'capitalExpenditures': '3691000000',
#    'changeInReceivables': 'None',
#    'changeInExchangeRate': 'None',
#    'changeInCashAndCashEquivalents': 'None'},
#   {'fiscalDateEnding': '2016-04-02',
#    'reportedCurrency': 'USD',
#    'investments': '42000000',
#    'changeInLiabilities': '-1035000000',
#    'cashflowFromInvestment': '-3038000000',
#    'otherCashflowFromInvestment': '0',
#    'netBorrowings': '2124000000',
#    'cashflowFromFinancing': '-1981000000',
#    'otherCashflowFromFinancing': '-444000000',
#    'changeInOperatingActivities': '-28000000',
#    'netIncome': '2143000000',
#    'changeInCash': '714000000',
#    'operatingCashflow': '5762000000',
#    'otherOperatingCashflow': 'None',
#    'depreciation': '0',
#    'dividendPayout': '-1168000000',
#    'stockSaleAndPurchase': '0',
#    'changeInInventory': '253000000',
#    'changeInAccountReceivables': '0',
#    'changeInNetIncome': '-412000000',
#    'capitalExpenditures': '2556000000',
#    'changeInReceivables': 'None',
#    'changeInExchangeRate': 'None',
#    'changeInCashAndCashEquivalents': 'None'},
#   {'fiscalDateEnding': '2016-01-02',
#    'reportedCurrency': 'USD',
#    'investments': 'None',
#    'changeInLiabilities': 'None',
#    'cashflowFromInvestment': '-1798000000',
#    'otherCashflowFromInvestment': '0',
#    'netBorrowings': 'None',
#    'cashflowFromFinancing': '-468000000',
#    'otherCashflowFromFinancing': '107000000',
#    'changeInOperatingActivities': 'None',
#    'netIncome': '2880000000',
#    'changeInCash': 'None',
#    'operatingCashflow': '2362000000',
#    'otherOperatingCashflow': 'None',
#    'depreciation': '0',
#    'dividendPayout': '0',
#    'stockSaleAndPurchase': '0',
#    'changeInInventory': '839000000',
#    'changeInAccountReceivables': '0',
#    'changeInNetIncome': 'None',
#    'capitalExpenditures': '1406000000',
#    'changeInReceivables': 'None',
#    'changeInExchangeRate': 'None',
#    'changeInCashAndCashEquivalents': 'None'},
#   {'fiscalDateEnding': '2015-10-03',
#    'reportedCurrency': 'USD',
#    'investments': '-850000000',
#    'changeInLiabilities': '-49000000',
#    'cashflowFromInvestment': '-4245000000',
#    'otherCashflowFromInvestment': '20000000',
#    'netBorrowings': '2705000000',
#    'cashflowFromFinancing': '-5801000000',
#    'otherCashflowFromFinancing': '610000000',
#    'changeInOperatingActivities': '223000000',
#    'netIncome': '1609000000',
#    'changeInCash': '1037000000',
#    'operatingCashflow': '10909000000',
#    'otherOperatingCashflow': 'None',
#    'depreciation': '2354000000',
#    'dividendPayout': '-3063000000',
#    'stockSaleAndPurchase': '0',
#    'changeInInventory': '1000000',
#    'changeInAccountReceivables': '-211000000',
#    'changeInNetIncome': '331000000',
#    'capitalExpenditures': '4265000000',
#    'changeInReceivables': 'None',
#    'changeInExchangeRate': 'None',
#    'changeInCashAndCashEquivalents': 'None'}]}

# %%
def alpha_get_annual_financial_statement(ticker, statement_type, api_key):
    """
    This function aims to retrieve the selected annual financial statements of a selected company
    available in alphavantage.co. Depending on availability, all years will be retrieved.

    :param ticker: listed company ticker
    :type ticker: str
    :param statement_type: type of financial statement (INCOME_STATEMENT, BALANCE_SHEET or CASH_FLOW)
    :type statement_type: str
    :param api_key: user's api key in alphavantage.co
    :type api_key: str
    :return: annual financial statements of the selected company
    :rtype: pd.DataFrame
    """

    annual_statement_response = requests.get("https://www.alphavantage.co/query?function={}&symbol={}&apikey={}"
                                             .format(statement_type, ticker, api_key))

    if annual_statement_response.status_code == 200:
        df_temp = pd.DataFrame({'Symbol': []})
        annual_statement = annual_statement_response.json().get('annualReports')
        df_annual_statement = pd.concat([df_temp, pd.DataFrame(annual_statement)], axis=1)
        df_annual_statement.iloc[:, 0] = annual_statement_response.json().get('symbol')
    else:
        print('Get annual {} failed with {}'
              .format(statement_type, annual_statement_response.status_code))

    return df_annual_statement

# %%
def alpha_get_company_profile_data(ticker, api_key):
    """
    This function aims to retrieve the selected company's profile data from alphavantage.co like market cap,
    industry, sector, beta etc.

    :param ticker: listed company ticker symbol
    :type ticker: str
    :param api_key: user's api key in alphavantage.co
    :type ticker: str
    :return: profile data of the selected company
    :rtype: pd.DataFrame
    """

    company_profile_response = requests.get("https://www.alphavantage.co/query?function=OVERVIEW&symbol={}&apikey={}"
                                            .format(ticker, api_key))

    if company_profile_response.status_code == 200:
        company_profile = [company_profile_response.json()]
    else:
        raise ValueError('Get {} company profile data failed with {}'
                         .format(ticker, company_profile_response.status_code))

    if pd.DataFrame(company_profile).empty:
        raise ValueError('No data retrieved! Check API!')

    return pd.DataFrame(company_profile)

# %%
alpha_get_company_profile_data('DIS', 'XHBL41C64CVIQFNJ')
# Out:
#   Symbol     AssetType                     Name  \
# 0    DIS  Common Stock  The Walt Disney Company
#
#                                          Description Exchange Currency  \
# 0  The Walt Disney Company, together with its sub...     NYSE      USD
#
#   Country                  Sector       Industry  \
# 0     USA  Communication Services  Entertainment
#
#                                              Address  ... ShortPercentFloat  \
# 0  500 South Buena Vista Street, Burbank, CA, Uni...  ...            0.0144
#
#   PercentInsiders PercentInstitutions ForwardAnnualDividendRate  \
# 0           0.202              66.286                         0
#
#   ForwardAnnualDividendYield PayoutRatio DividendDate ExDividendDate  \
# 0                          0      0.7686   2020-01-16     2019-12-13
#
#   LastSplitFactor LastSplitDate
# 0      10000:9865    2007-06-13
#
# [1 rows x 59 columns]

# %%
alpha_get_annual_financial_statement('DIS', 'INCOME_STATEMENT', 'XHBL41C64CVIQFNJ')
# Out:
#   symbol fiscalDateEnding reportedCurrency totalRevenue totalOperatingExpense  \
# 0    DIS       2019-09-30              USD  69570000000           57719000000
# 1    DIS       2018-09-30              USD  59434000000           44597000000
# 2    DIS       2017-09-30              USD  55137000000           41264000000
# 3    DIS       2016-10-01              USD  55632000000           41274000000
# 4    DIS       2016-09-30              USD  55632000000           41274000000
#
#   costOfRevenue  grossProfit         ebit    netIncome researchAndDevelopment  \
# 0   42018000000  27552000000  19350000000  11054000000                   None
# 1   32726000000  26708000000  18422000000  12598000000                      0
# 2   30306000000  24831000000  17077000000   8980000000                      0
# 3   29993000000  25639000000  17749000000   9391000000                      0
# 4   29993000000  25639000000  17749000000   9391000000                   None
#
#    ... netInterestIncome extraordinaryItems nonRecurring otherItems  \
# 0  ...        -978000000          647000000         None       None
# 1  ...        -574000000         1700000000         None       None
# 2  ...        -385000000               None     98000000       None
# 3  ...        -260000000               None    156000000       None
# 4  ...        -260000000               None         None       None
#
#   incomeTaxExpense totalOtherIncomeExpense discontinuedOperations  \
# 0       3031000000              3071000000              613000000
# 1       1663000000               466000000              613000000
# 2       4422000000               300000000              613000000
# 3       5078000000               770000000              613000000
# 4       5078000000               770000000              613000000
#
#   netIncomeFromContinuingOperations netIncomeApplicableToCommonShares  \
# 0                       10913000000                       11054000000
# 1                       13066000000                       12598000000
# 2                        9366000000                        8980000000
# 3                        9790000000                        9391000000
# 4                        9790000000                        9391000000
#
#   preferredStockAndOtherAdjustments
# 0                              None
# 1                              None
# 2                              None
# 3                              None
# 4                              None
#
# [5 rows x 30 columns]

# %%
def alpha_collect_companies_data(tickers_list, api_key):
    """
    This function aims to collect all financial data from the income, balance sheet and cash flow statement of all the
    selected companies in the tickers_list and combine them into a pandas dataset.
    Companies' profile data will be collected here and will be returned as a second pandas dataset

    :param tickers_list: a list of tickers that should be collected
    :type tickers_list: list
    :param api_key: user's api key in alphavantage.co
    :type api_key: str
    :return: a dataframe with financial data from the selected companies
    :rtype: pd.DataFrame
    :return: a dataframe with profile data from the selected companies
    :rtype: pd.DataFrame
    """

    companies_profile_data = pd.DataFrame()
    companies_financial_data = pd.DataFrame()

    try:
        for ticker in tickers_list:
            print('        Getting {} data...'.format(ticker))
            # get current company's financial and profile data
            profile_data = alpha_get_company_profile_data(ticker, api_key)
            income_statement = alpha_get_annual_financial_statement(ticker, 'INCOME_STATEMENT', api_key)
            balance_sheet_statement = alpha_get_annual_financial_statement(ticker, 'BALANCE_SHEET', api_key)
            cash_flow_statement = alpha_get_annual_financial_statement(ticker, 'CASH_FLOW', api_key)

            # concatenate data from all 3 financial statements horizontally
            financial_data = pd.concat([income_statement, balance_sheet_statement, cash_flow_statement], axis=1)

            # append retrieved data of the current company to the final dataframes
            companies_financial_data = companies_financial_data.append(financial_data, ignore_index=True)
            companies_profile_data = companies_profile_data.append(profile_data, ignore_index=True)
            print('        {} data received!'.format(ticker))
    except ValueError:
        print('Data collection interrupted! Continuing rest of the process..')

    companies_financial_data = companies_financial_data.loc[:, ~companies_financial_data.columns.duplicated()]

    return companies_financial_data, companies_profile_data

# %%
companies_list = ['AAPL', 'GOOG']

df_financial_data, df_profile_data = alpha_collect_companies_data(companies_list, alpha_api_key)

# %%
df_financial_data
# Out:
#   symbol fiscalDateEnding reportedCurrency  totalRevenue  \
# 0   AAPL       2019-09-30              USD  260174000000
# 1   AAPL       2018-09-30              USD  265595000000
# 2   AAPL       2017-09-30              USD  229234000000
# 3   AAPL       2016-09-30              USD  215639000000
# 4   AAPL       2015-09-30              USD  233715000000
# 5   GOOG       2019-12-31              USD  161857000000
# 6   GOOG       2018-12-31              USD  136819000000
# 7   GOOG       2017-12-31              USD  110855000000
# 8   GOOG       2016-12-31              USD   90272000000
# 9   GOOG       2015-12-31              USD   74989000000
#
#   totalOperatingExpense costOfRevenue   grossProfit         ebit    netIncome  \
# 0          196244000000  161782000000   98392000000  81860000000  55256000000
# 1          194697000000  163756000000  101839000000  87046000000  59531000000
# 2          167890000000  141048000000   88186000000  76569000000  48351000000
# 3          155615000000  131376000000   84263000000  73333000000  45687000000
# 4           22396000000  140089000000   93626000000  71230000000  53394000000
# 5          125929000000   71896000000   89961000000  51506000000  34343000000
# 6          105427000000   59549000000   77270000000  44062000000  30736000000
# 7           81973000000   45583000000   65272000000  34217000000  12662000000
# 8           66556000000   35138000000   55134000000  30418000000  19478000000
# 9           27465000000   28164000000   46825000000  19360000000  16348000000
#
#   researchAndDevelopment  ... depreciation dividendPayout  \
# 0            16217000000  ...  12547000000   -14119000000
# 1            14236000000  ...  10903000000   -13712000000
# 2            11581000000  ...  10157000000   -12769000000
# 3            10045000000  ...  10505000000   -12150000000
# 4             8067000000  ...  11257000000   -11561000000
# 5            26018000000  ...  11781000000           None
# 6            21419000000  ...   9035000000           None
# 7            16625000000  ...   6915000000              0
# 8            13948000000  ...   6144000000              0
# 9            12282000000  ...   4132000000      -47000000
#
#   stockSaleAndPurchase changeInInventory changeInAccountReceivables  \
# 0         -66897000000        -289000000                  245000000
# 1         -72738000000         828000000                -5322000000
# 2         -32900000000       -2723000000                -2093000000
# 3         -29722000000         217000000                 1095000000
# 4         -34710000000        -238000000                  417000000
# 5         -18396000000              None                -4340000000
# 6          -9075000000              None                -2169000000
# 7          -4846000000                 0                -3768000000
# 8          -3693000000                 0                -2578000000
# 9          -1780000000                 0                -2094000000
#
#   changeInNetIncome capitalExpenditures changeInReceivables  \
# 0        5076000000         10495000000          3176000000
# 1      -27694000000         13313000000        -13332000000
# 2       10640000000         12795000000         -6347000000
# 3        9634000000         13548000000          1044000000
# 4        5353000000         11247000000           611000000
# 5        7707000000         23548000000         -4340000000
# 6        3298000000         25139000000         -2169000000
# 7        8284000000         13184000000         -3768000000
# 8        7158000000         10212000000         -2578000000
# 9        4688000000          9950000000         -2094000000
#
#   changeInExchangeRate changeInCashAndCashEquivalents
# 0                 None                    24311000000
# 1                 None                     5624000000
# 2                 None                     -195000000
# 3                 None                     -636000000
# 4                 None                     7276000000
# 5                 None                     1820000000
# 6           -302000000                     5986000000
# 7            405000000                    -2203000000
# 8           -170000000                    -3631000000
# 9           -434000000                    -1798000000
#
# [10 rows x 100 columns]

# %%
df_profile_data
# Out:
#   Symbol     AssetType          Name  \
# 0   AAPL  Common Stock     Apple Inc
# 1   GOOG  Common Stock  Alphabet Inc
#
#                                          Description Exchange Currency  \
# 0  Apple Inc. designs, manufactures, and markets ...   NASDAQ      USD
# 1  Alphabet Inc. provides online advertising serv...   NASDAQ      USD
#
#   Country                  Sector                        Industry  \
# 0     USA              Technology            Consumer Electronics
# 1     USA  Communication Services  Internet Content & Information
#
#                                              Address  ... ShortPercentFloat  \
# 0  One Apple Park Way, Cupertino, CA, United Stat...  ...            0.0082
# 1  1600 Amphitheatre Parkway, Mountain View, CA, ...  ...                 0
#
#   PercentInsiders PercentInstitutions ForwardAnnualDividendRate  \
# 0           0.066              62.115                      3.28
# 1           5.746               70.62                         0
#
#   ForwardAnnualDividendYield PayoutRatio DividendDate ExDividendDate  \
# 0                     0.0072      0.2373   2020-08-13     2020-08-07
# 1                          0           0         None           None
#
#   LastSplitFactor LastSplitDate
# 0             7:1    2014-06-09
# 1      10000000:1    2015-04-27
#
# [2 rows x 59 columns]

# %%
# check for any NaNs that are results from concatenating missing columns
sum(df_financial_data.isna().sum()), sum(df_profile_data.isna().sum())
# Out:
# (0, 0)

# %%
df_financial_data.shape, df_profile_data.shape
# Out:
# ((10, 100), (2, 59))

# %%
def save_data(df, database_filename, table_name):
    """
    This function aims to save a dataset into a sqlite database with the provided name.

    :param df: a dataframe that consists of disaster messages and corresponding categories
    :type df: pd.DataFrame
    :param database_filename: name of the sqlite database
    :type database_filename: str
    :param table_name: name of the SQL table
    :type table_name: str
    :return: none
    """

    engine = create_engine('sqlite:///{}'.format(database_filename))
    df.to_sql(table_name, engine, index=False, if_exists='replace')

# %%
database_filepath = './data/CompanyData.db'
save_data(df_financial_data, database_filepath, 'FinancialStatementsTable')
save_data(df_profile_data, database_filepath, 'CompanyProfileTable')

# %% [markdown]
# # Get symbol list

# %% [markdown]
# get all avaliable companies in financialmodelingprep.com

# %%
# get request for symbol list
symbol_list_response = requests.get("https://financialmodelingprep.com/api/v3/stock/list?apikey=08f03438c8b31a22e58ce3ec9f6dabf6")

# %%
# convert symbol list to dataframe
symbol_list = symbol_list_response.json()
df_symbols = pd.DataFrame(symbol_list)
df_symbols.head()
# Out:
#   symbol                                      name   price  \
# 0    SPY                              SPDR S&P 500  334.57
# 1  CMCSA  Comcast Corporation Class A Common Stock   42.81
# 2    KMI                        Kinder Morgan Inc.   14.32
# 3   INTC                         Intel Corporation   48.03
# 4     MU                    Micron Technology Inc.   48.75
#
#                   exchange
# 0                NYSE Arca
# 1     Nasdaq Global Select
# 2  New York Stock Exchange
# 3     Nasdaq Global Select
# 4     Nasdaq Global Select

# %%
# check number of elements in df_symbols
df_symbols.shape
# Out:
# (14369, 4)

# %%
# check the number of companies in each stock exchange
df_symbols.exchange.value_counts()
# Out:
# New York Stock Exchange    2602
# NYSE Arca                  1540
# Nasdaq                     1537
# Nasdaq Global Select       1504
# Toronto                    1197
# NASDAQ Capital Market       878
# Paris                       858
# NASDAQ Global Market        847
# NasdaqGS                    587
# NYSE                        457
# NasdaqCM                    404
# NYSE American               353
# NYSEArca                    339
# BATS Exchange               258
# YHD                         255
# Brussels                    165
# NasdaqGM                    159
# BATS                        144
# Amsterdam                   133
# Lisbon                       51
# Other OTC                    11
# MCX                           8
# Swiss                         1
# Name: exchange, dtype: int64

# %% [markdown]
# # Get data of all S&P 500 companies

# %%
def load_existing_data(database_filepath):
    """
    This functions aims to load and return the FinancialStatementTable and CompanyProfileTable saved in the database
    given in database_filepath as 2 separate dataframes. If the given database or the tables do not exist,
    this function will return empty dataframes.

    :param database_filepath: file path with the name of the sql database to access
    :type database_filepath: str
    :return: FinancialStatementsTable and CompanyProfile as dataframes, empty dataframes if they do not exist
    :rtype: pd.DataFrame
    """
    df_financial_statements = pd.DataFrame()
    df_profile = pd.DataFrame()


    try:
        engine = create_engine('sqlite:///{}'.format(database_filepath))
    except:
        print('    CompanyData.db does not exist')

    try:
        df_financial_statements = pd.read_sql_table('FinancialStatementsTable', engine)
    except:
        print('    FinancialStatementsTable does not exist in CompanyData.db')

    try:
        df_profile = pd.read_sql_table('CompanyProfileTable', engine)
    except:
        print('    CompanyProfileTable does not exist in CompanyData.db')

    return df_financial_statements, df_profile

# %%
df_financial_statements, df_profile = load_existing_data('./data/CompanyData.db')

# %%
def compare_lists(list1, list2):
    """
    This function aims to list out all the mismatched elements in two lists.
    
    """
    missing_elements = []
    count = 0
    
    if len(list1) > len(list2):
        for ele in list1:
            if(ele not in list2):
                missing_elements.append(ele)
    else:
        for ele in list2:
            if(ele not in list1):
                missing_elements.append(ele)            
            
    return missing_elements

# %%
# check if there are any mismtached elements between the data before and after saving data to sql
compare_lists(df_financial_statements.columns.tolist(), df_financial_data.columns.tolist())
# Out:
# []

# %%
# see if the number of columns in the dataframes before and after saving data to sql is the same
len(df_financial_statements.columns), len(df_financial_data.columns)
# Out:
# (99, 99)

# %%
# load S&P 500 data from barchart.com downloaded on 08.08.2020
companies = pd.read_csv('./data/sp-500-index.csv', header=None).iloc[:,0].unique()
companies_list = companies.tolist()
companies_list
# Out:
# ['A',
#  'AAL',
#  'AAP',
#  'AAPL',
#  'ABBV',
#  'ABC',
#  'ABMD',
#  'ABT',
#  'ACN',
#  'ADBE',
#  'ADI',
#  'ADM',
#  'ADP',
#  'ADSK',
#  'AEE',
#  'AEP',
#  'AES',
#  'AFL',
#  'AIG',
#  'AIV',
#  'AIZ',
#  'AJG',
#  'AKAM',
#  'ALB',
#  'ALGN',
#  'ALK',
#  'ALL',
#  'ALLE',
#  'ALXN',
#  'AMAT',
#  'AMCR',
#  'AMD',
#  'AME',
#  'AMGN',
#  'AMP',
#  'AMT',
#  'AMZN',
#  'ANET',
#  'ANSS',
#  'ANTM',
#  'AON',
#  'AOS',
#  'APA',
#  'APD',
#  'APH',
#  'APTV',
#  'ARE',
#  'ATO',
#  'ATVI',
#  'AVB',
#  'AVGO',
#  'AVY',
#  'AWK',
#  'AXP',
#  'AZO',
#  'BA',
#  'BAC',
#  'BAX',
#  'BBY',
#  'BDX',
#  'BEN',
#  'BF.B',
#  'BIIB',
#  'BIO',
#  'BK',
#  'BKNG',
#  'BKR',
#  'BLK',
#  'BLL',
#  'BMY',
#  'BR',
#  'BRK.B',
#  'BSX',
#  'BWA',
#  'BXP',
#  'C',
#  'CAG',
#  'CAH',
#  'CARR',
#  'CAT',
#  'CB',
#  'CBOE',
#  'CBRE',
#  'CCI',
#  'CCL',
#  'CDNS',
#  'CDW',
#  'CE',
#  'CERN',
#  'CF',
#  'CFG',
#  'CHD',
#  'CHRW',
#  'CHTR',
#  'CI',
#  'CINF',
#  'CL',
#  'CLX',
#  'CMA',
#  'CMCSA',
#  'CME',
#  'CMG',
#  'CMI',
#  'CMS',
#  'CNC',
#  'CNP',
#  'COF',
#  'COG',
#  'COO',
#  'COP',
#  'COST',
#  'COTY',
#  'CPB',
#  'CPRT',
#  'CRM',
#  'CSCO',
#  'CSX',
#  'CTAS',
#  'CTL',
#  'CTSH',
#  'CTVA',
#  'CTXS',
#  'CVS',
#  'CVX',
#  'CXO',
#  'D',
#  'DAL',
#  'DD',
#  'DE',
#  'DFS',
#  'DG',
#  'DGX',
#  'DHI',
#  'DHR',
#  'DIS',
#  'DISCA',
#  'DISCK',
#  'DISH',
#  'DLR',
#  'DLTR',
#  'DOV',
#  'DOW',
#  'DPZ',
#  'DRE',
#  'DRI',
#  'DTE',
#  'DUK',
#  'DVA',
#  'DVN',
#  'DXC',
#  'DXCM',
#  'EA',
#  'EBAY',
#  'ECL',
#  'ED',
#  'EFX',
#  'EIX',
#  'EL',
#  'EMN',
#  'EMR',
#  'EOG',
#  'EQIX',
#  'EQR',
#  'ES',
#  'ESS',
#  'ETFC',
#  'ETN',
#  'ETR',
#  'EVRG',
#  'EW',
#  'EXC',
#  'EXPD',
#  'EXPE',
#  'EXR',
#  'F',
#  'FANG',
#  'FAST',
#  'FB',
#  'FBHS',
#  'FCX',
#  'FDX',
#  'FE',
#  'FFIV',
#  'FIS',
#  'FISV',
#  'FITB',
#  'FLIR',
#  'FLS',
#  'FLT',
#  'FMC',
#  'FOX',
#  'FOXA',
#  'FRC',
#  'FRT',
#  'FTI',
#  'FTNT',
#  'FTV',
#  'GD',
#  'GE',
#  'GILD',
#  'GIS',
#  'GL',
#  'GLW',
#  'GM',
#  'GOOG',
#  'GOOGL',
#  'GPC',
#  'GPN',
#  'GPS',
#  'GRMN',
#  'GS',
#  'GWW',
#  'HAL',
#  'HAS',
#  'HBAN',
#  'HBI',
#  'HCA',
#  'HD',
#  'HES',
#  'HFC',
#  'HIG',
#  'HII',
#  'HLT',
#  'HOLX',
#  'HON',
#  'HPE',
#  'HPQ',
#  'HRB',
#  'HRL',
#  'HSIC',
#  'HST',
#  'HSY',
#  'HUM',
#  'HWM',
#  'IBM',
#  'ICE',
#  'IDXX',
#  'IEX',
#  'IFF',
#  'ILMN',
#  'INCY',
#  'INFO',
#  'INTC',
#  'INTU',
#  'IP',
#  'IPG',
#  'IPGP',
#  'IQV',
#  'IR',
#  'IRM',
#  'ISRG',
#  'IT',
#  'ITW',
#  'IVZ',
#  'J',
#  'JBHT',
#  'JCI',
#  'JKHY',
#  'JNJ',
#  'JNPR',
#  'JPM',
#  'K',
#  'KEY',
#  'KEYS',
#  'KHC',
#  'KIM',
#  'KLAC',
#  'KMB',
#  'KMI',
#  'KMX',
#  'KO',
#  'KR',
#  'KSS',
#  'KSU',
#  'L',
#  'LB',
#  'LDOS',
#  'LEG',
#  'LEN',
#  'LH',
#  'LHX',
#  'LIN',
#  'LKQ',
#  'LLY',
#  'LMT',
#  'LNC',
#  'LNT',
#  'LOW',
#  'LRCX',
#  'LUV',
#  'LVS',
#  'LW',
#  'LYB',
#  'LYV',
#  'MA',
#  'MAA',
#  'MAR',
#  'MAS',
#  'MCD',
#  'MCHP',
#  'MCK',
#  'MCO',
#  'MDLZ',
#  'MDT',
#  'MET',
#  'MGM',
#  'MHK',
#  'MKC',
#  'MKTX',
#  'MLM',
#  'MMC',
#  'MMM',
#  'MNST',
#  'MO',
#  'MOS',
#  'MPC',
#  'MRK',
#  'MRO',
#  'MS',
#  'MSCI',
#  'MSFT',
#  'MSI',
#  'MTB',
#  'MTD',
#  'MU',
#  'MXIM',
#  'MYL',
#  'NBL',
#  'NCLH',
#  'NDAQ',
#  'NEE',
#  'NEM',
#  'NFLX',
#  'NI',
#  'NKE',
#  'NLOK',
#  'NLSN',
#  'NOC',
#  'NOV',
#  'NOW',
#  'NRG',
#  'NSC',
#  'NTAP',
#  'NTRS',
#  'NUE',
#  'NVDA',
#  'NVR',
#  'NWL',
#  'NWS',
#  'NWSA',
#  'O',
#  'ODFL',
#  'OKE',
#  'OMC',
#  'ORCL',
#  'ORLY',
#  'OTIS',
#  'OXY',
#  'OXY.W',
#  'PAYC',
#  'PAYX',
#  'PBCT',
#  'PCAR',
#  'PEAK',
#  'PEG',
#  'PEP',
#  'PFE',
#  'PFG',
#  'PG',
#  'PGR',
#  'PH',
#  'PHM',
#  'PKG',
#  'PKI',
#  'PLD',
#  'PM',
#  'PNC',
#  'PNR',
#  'PNW',
#  'PPG',
#  'PPL',
#  'PRGO',
#  'PRU',
#  'PSA',
#  'PSX',
#  'PVH',
#  'PWR',
#  'PXD',
#  'PYPL',
#  'QCOM',
#  'QRVO',
#  'RCL',
#  'RE',
#  'REG',
#  'REGN',
#  'RF',
#  'RHI',
#  'RJF',
#  'RL',
#  'RMD',
#  'ROK',
#  'ROL',
#  'ROP',
#  'ROST',
#  'RSG',
#  'RTX',
#  'SBAC',
#  'SBUX',
#  'SCHW',
#  'SEE',
#  'SHW',
#  'SIVB',
#  'SJM',
#  'SLB',
#  'SLG',
#  'SNA',
#  'SNPS',
#  'SO',
#  'SPG',
#  'SPGI',
#  'SRE',
#  'STE',
#  'STT',
#  'STX',
#  'STZ',
#  'SWK',
#  'SWKS',
#  'SYF',
#  'SYK',
#  'SYY',
#  'T',
#  'TAP',
#  'TDG',
#  'TDY',
#  'TEL',
#  'TFC',
#  'TFX',
#  'TGT',
#  'TIF',
#  'TJX',
#  'TMO',
#  'TMUS',
#  'TPR',
#  'TROW',
#  'TRV',
#  'TSCO',
#  'TSN',
#  'TT',
#  'TTWO',
#  'TWTR',
#  'TXN',
#  'TXT',
#  'TYL',
#  'UA',
#  'UAA',
#  'UAL',
#  'UDR',
#  'UHS',
#  'ULTA',
#  'UNH',
#  'UNM',
#  'UNP',
#  'UPS',
#  'URI',
#  'USB',
#  'V',
#  'VAR',
#  'VFC',
#  'VIAC',
#  'VLO',
#  'VMC',
#  'VNO',
#  'VRSK',
#  'VRSN',
#  'VRTX',
#  'VTR',
#  'VZ',
#  'WAB',
#  'WAT',
#  'WBA',
#  'WDC',
#  'WEC',
#  'WELL',
#  'WFC',
#  'WHR',
#  'WLTW',
#  'WM',
#  'WMB',
#  'WMT',
#  'WRB',
#  'WRK',
#  'WST',
#  'WU',
#  'WY',
#  'WYNN',
#  'XEL',
#  'XLNX',
#  'XOM',
#  'XRAY',
#  'XRX',
#  'XYL',
#  'YUM',
#  'ZBH',
#  'ZBRA',
#  'ZION',
#  'ZTS']

# %%
#test
companies_list = ['AAPL', 'GOOG', 'FB', 'AMZN']

def update_database(companies_list, database_filepath, api_key):
    """
    This function aims to update the given database with the financial and profile data of the selected companies
    in companies_list from financialmodelingprep.com. If the companies' data already exist in the given database,
    the corresponding data will not be retrieved.

    :param companies_list: list of companies whose data should be retrieved from financialmodelingprep.com
    :type companies_list: list
    :param database_filepath: path to the sqlite database
    :type database_filepath: str
    :param api_key: user's api key in financialmodelingprep.com
    :type api_key: str
    :return: none
    """

    missing_companies_list = []

    # load companies' financial statements and profile data dataframes from the given database
    print('    Loading database...')
    df_financial_statements, df_profile = load_existing_data(database_filepath)

    # if no data exists in the database at all, collect data for all companies in companies_list
    if df_financial_statements.empty | df_profile.empty:
        print('    Tables are empty. Getting data from all companies...')
        df_financial_statements, df_profile = collect_companies_data(companies_list, api_key)

        # saving the updated financial statements and profile dataframes to the database
        save_data(df_financial_statements, database_filepath, 'FinancialStatementsTable')
        save_data(df_profile, database_filepath, 'CompanyProfileTable')
        print('    Tables updated!')
    # if some data exists in the database already, select only the missing ones
    else:
        # select the missing companies' symbols from companies_list.
        for symbol in companies_list:
            if symbol not in df_profile.Symbol.tolist():
                missing_companies_list.append(symbol)

        if not missing_companies_list:
            print('    No new company to be added to database. Tables are up-to-date!')
        else:
            # update the missing companies' financial statements and profile dataframes
            print('    Tables are out-of-date. Getting data from all companies...')
            new_financial_statements, new_profile = collect_companies_data(missing_companies_list, api_key)
            df_financial_statements = df_financial_statements.append(new_financial_statements, ignore_index=True)
            df_profile = df_profile.append(new_profile, ignore_index=True)

            # saving the updated financial statements and profile dataframes to the database
            save_data(df_financial_statements, database_filepath, 'FinancialStatementsTable')
            save_data(df_profile, database_filepath, 'CompanyProfileTable')
            print('    Tables updated!')

# %%
update_database(companies_list, database_filepath, api_key)
# Out:
#     Loading database...
#     No new company to be added to database. Tables are up-to-date!

# %%
new_financial_statements, new_profile = load_existing_data('./data/CompanyData.db')

# %%
new_financial_statements
# Out:
#   Symbol fiscalDateEnding reportedCurrency totalRevenue totalOperatingExpense  \
# 0      A       2019-10-31              USD   5163000000            4222000000
# 1      A       2018-10-31              USD   4914000000            3986000000
# 2      A       2017-10-31              USD   4472000000            3631000000
# 3      A       2016-10-31              USD   4202000000            3587000000
# 4      A       2015-10-31              USD   4038000000            3513000000
#
#   costOfRevenue grossProfit        ebit   netIncome researchAndDevelopment  \
# 0    2358000000  2805000000  1231000000  1071000000              404000000
# 1    2227000000  2687000000  1231000000   316000000              385000000
# 2    2063000000  2409000000  1094000000   684000000              339000000
# 3    2005000000  2197000000   862000000   462000000              329000000
# 4    2015000000  2023000000   525000000   401000000              327000000
#
#    ... depreciation dividendPayout stockSaleAndPurchase changeInInventory  \
# 0  ...    238000000     -206000000           -723000000         -36000000
# 1  ...    210000000     -191000000           -422000000         -83000000
# 2  ...    212000000     -170000000           -194000000         -61000000
# 3  ...    246000000     -150000000           -434000000          -7000000
# 4  ...    253000000     -133000000           -209000000         -24000000
#
#   changeInAccountReceivables changeInNetIncome capitalExpenditures  \
# 0                 -106000000        -149000000           156000000
# 1                  -65000000          90000000           177000000
# 2                  -81000000         193000000           176000000
# 3                  -33000000         125000000           139000000
# 4                  -24000000         983000000            98000000
#
#   changeInReceivables changeInExchangeRate changeInCashAndCashEquivalents
# 0          -106000000              2000000                     -866000000
# 1           -65000000            -17000000                     -431000000
# 2           -81000000              7000000                      389000000
# 3           -33000000             -1000000                      286000000
# 4           -24000000            -48000000                    -1025000000
#
# [5 rows x 100 columns]

# %%
new_profile
# Out:
#   Symbol     AssetType                       Name  \
# 0      A  Common Stock  Agilent Technologies, Inc
#
#                                          Description Exchange Currency  \
# 0  Agilent Technologies, Inc. provides applicatio...     NYSE      USD
#
#   Country      Sector                Industry  \
# 0     USA  Healthcare  Diagnostics & Research
#
#                                              Address  ... ShortPercentFloat  \
# 0  5301 Stevens Creek Boulevard, Santa Clara, CA,...  ...            0.0134
#
#   PercentInsiders PercentInstitutions ForwardAnnualDividendRate  \
# 0           0.373              89.387                      0.72
#
#   ForwardAnnualDividendYield PayoutRatio DividendDate ExDividendDate  \
# 0                     0.0074      0.3142   2020-07-22     2020-06-29
#
#   LastSplitFactor LastSplitDate
# 0       1398:1000    2014-11-03
#
# [1 rows x 59 columns]
